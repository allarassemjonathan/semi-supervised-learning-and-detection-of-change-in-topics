# %%
from re import match

topic_txt = open('topic_modeling.txt','r')
topics = {}
cur_topic = None
for line in topic_txt.readlines():
    m = match(' Topic # (\d+) = (\w+)', line)
    if m:
        cur_topic = (m.group(2), int(m.group(1)))
        topics[cur_topic]  = {}
    elif cur_topic is not None:
        m = match("\(\'(\w+)\', (\d+)\)", line)
        if m:
            topics[cur_topic][m.group(1)] = int(m.group(2))
topics
# Out:
# {('thank', 0): {'thank': 36,
#   'happy': 17,
#   'proud': 13,
#   'help': 11,
#   'today': 8,
#   'thanks': 7,
#   'every': 7,
#   'people': 7,
#   'like': 6,
#   'wonderful': 6,
#   'great': 6,
#   'day': 6,
#   'family': 6,
#   'good': 6,
#   'make': 5,
#   'love': 5,
#   'congratulation': 5,
#   'well': 5,
#   'year': 5,
#   'many': 5,
#   'share': 5,
#   'work': 4,
#   'ever': 4,
#   'everyone': 4,
#   'hope': 4,
#   'donation': 4,
#   'serve': 4,
#   'moment': 4,
#   'going': 4,
#   'birthday': 4,
#   'team': 4,
#   'leadership': 3,
#   'another': 3,
#   'union': 3,
#   'congress': 3,
#   'community': 3,
#   'organizer': 3,
#   'bronx': 3,
#   'welcome': 3,
#   'working': 3,
#   'could': 3,
#   'worked': 3,
#   'last': 3,
#   'country': 3,
#   'reminder': 3,
#   'ny': 3,
#   'always': 3,
#   'meeting': 3,
#   'home': 3,
#   'back': 3,
#   'life': 3,
#   'abzug': 3,
#   'others': 3,
#   'time': 3,
#   'want': 3,
#   'effort': 3,
#   'bella': 2,
#   'strong': 2,
#   'state': 2,
#   'strike': 2,
#   'inspiration': 2,
#   'first': 2,
#   'remarkable': 2,
#   'right': 2,
#   'sign': 2,
#   'library': 2,
#   'inside': 2,
#   'supporter': 2,
#   'truly': 2,
#   'champion': 2,
#   'relief': 2,
#   'bring': 2,
#   'stand': 2,
#   'beach': 2,
#   'showing': 2,
#   'organize': 2,
#   'collective': 2,
#   'girl': 2,
#   'small': 2,
#   'heart': 2,
#   'across': 2,
#   'days': 2,
#   'culture': 2,
#   'glad': 2,
#   'ring': 2,
#   'true': 2,
#   'enjoy': 2,
#   'keep': 2,
#   'driver': 2,
#   'word': 2,
#   'volunteer': 2,
#   'hunger': 2,
#   'let': 2,
#   'congressman': 2,
#   'helping': 2,
#   'buffalo': 2,
#   'student': 2,
#   'seems': 2,
#   'call': 2,
#   'friend': 2,
#   'please': 2,
#   'worker': 2,
#   'news': 2,
#   'magdalena': 2,
#   'struggle': 2,
#   'honor': 2,
#   'fight': 2,
#   'huge': 2,
#   'original': 2,
#   'making': 2,
#   'need': 2,
#   'wishing': 2,
#   'solidarity': 2,
#   'men': 2,
#   'writing': 2,
#   'grateful': 2,
#   'everything': 2,
#   'special': 2,
#   'advocate': 2,
#   'donate': 2,
#   'meaningful': 2,
#   'covid': 2,
#   'possible': 2,
#   'shout': 2,
#   'grace': 2,
#   'take': 2,
#   'night': 2,
#   'incredible': 2,
#   'season': 2,
#   'tirelessly': 2,
#   'soon': 2,
#   'look': 2,
#   'nothing': 2,
#   'president': 2,
#   'anniversary': 1,
#   'role': 1,
#   'one': 1,
#   'similar': 1,
#   'sure': 1,
#   'apparently': 1,
#   'walton': 1,
#   'success': 1,
#   'earned': 1,
#   'direct': 1,
#   'way': 1,
#   'yeah': 1,
#   'enthusiasm': 1,
#   'responsibility': 1,
#   'seeing': 1,
#   'delegation': 1,
#   'public': 1,
#   'wonder': 1,
#   'better': 1,
#   'rally': 1,
#   'fave': 1,
#   'mentor': 1,
#   'palestinian': 1,
#   'existence': 1,
#   'discus': 1,
#   'anyways': 1,
#   'note': 1,
#   'throughout': 1,
#   'though': 1,
#   'also': 1,
#   'unionized': 1,
#   'indigenous': 1,
#   'entrusting': 1,
#   'ups': 1,
#   'featuring': 1,
#   'picket': 1,
#   'east': 1,
#   'future': 1,
#   'dara': 1,
#   'done': 1,
#   'camping': 1,
#   'justice': 1,
#   'join': 1,
#   'hand': 1,
#   'produce': 1,
#   'hermanita': 1,
#   'cruz': 1,
#   'bumping': 1,
#   'spirit': 1,
#   'bear': 1,
#   'starbucks': 1,
#   'standing': 1,
#   'inspiring': 1,
#   'notmeus': 1,
#   'slouch': 1,
#   'program': 1,
#   'courage': 1,
#   'serving': 1,
#   'receiving': 1,
#   'campaign': 1,
#   'continue': 1,
#   'appreciate': 1,
#   'guidance': 1,
#   'generously': 1,
#   'owen': 1,
#   'super': 1,
#   'congresswoman': 1,
#   'greatest': 1,
#   'vice': 1,
#   'side': 1,
#   'elmhurst': 1,
#   'gain': 1,
#   'anything': 1,
#   'graduated': 1,
#   'brilliant': 1,
#   'constantly': 1,
#   'arawak': 1,
#   'representing': 1,
#   'beautiful': 1,
#   'u': 1,
#   'likewise': 1,
#   'mayor': 1,
#   'discounting': 1,
#   'wood': 1,
#   'smell': 1,
#   'breakthrough': 1,
#   'connecting': 1,
#   'westchester': 1,
#   'powerful': 1,
#   'recipient': 1,
#   'know': 1,
#   'confidence': 1,
#   'standard': 1,
#   'must': 1,
#   'almost': 1,
#   'cleaner': 1,
#   'became': 1,
#   'papa': 1,
#   'bravery': 1,
#   'pretty': 1,
#   'phone': 1,
#   'visiting': 1,
#   'endured': 1,
#   'meanwhile': 1,
#   'constituent': 1,
#   'impressive': 1,
#   'visited': 1,
#   'coming': 1,
#   'queen': 1,
#   'evening': 1,
#   'throwing': 1,
#   'ancestors': 1,
#   'learn': 1,
#   'sometime': 1,
#   'history': 1,
#   'month': 1,
#   'lead': 1,
#   'amplified': 1,
#   'engaging': 1,
#   'brought': 1,
#   'artist': 1,
#   'performer': 1,
#   'generosity': 1,
#   'taking': 1,
#   'official': 1,
#   'begin': 1,
#   'even': 1,
#   'deco': 1,
#   'scottish': 1,
#   'event': 1,
#   'friendship': 1,
#   'memories': 1,
#   'oftentimes': 1,
#   'creating': 1,
#   'nationally': 1,
#   'least': 1,
#   'jamie': 1,
#   'luck': 1,
#   'rabbi': 1,
#   'nurse': 1,
#   'party': 1,
#   'image': 1,
#   'resignation': 1,
#   'store': 1,
#   'asks': 1,
#   'icon': 1,
#   'point': 1,
#   'witness': 1,
#   'baby': 1,
#   'funeral': 1,
#   'allen': 1,
#   'pizza': 1,
#   'contributes': 1,
#   'comment': 1,
#   'pinch': 1,
#   'recovery': 1,
#   'rep': 1,
#   'prep': 1,
#   'daughter': 1,
#   'square': 1,
#   'pave': 1,
#   'much': 1,
#   'shift': 1,
#   'eastern': 1,
#   'line': 1,
#   'school': 1,
#   'servant': 1,
#   'raised': 1,
#   'scientist': 1,
#   'leader': 1,
#   'principal': 1,
#   'representative': 1,
#   'busting': 1,
#   'win': 1,
#   'build': 1,
#   'grassroots': 1,
#   'delivered': 1,
#   'thing': 1,
#   'little': 1,
#   'mother': 1,
#   'wire': 1,
#   'pregnant': 1,
#   'content': 1,
#   'story': 1,
#   'experience': 1,
#   'wish': 1,
#   'open': 1,
#   'andy': 1,
#   'thrift': 1,
#   'sen': 1,
#   'assistance': 1,
#   'seen': 1,
#   'list': 1,
#   'reflected': 1,
#   'saturday': 1,
#   'quickly': 1,
#   'rooting': 1,
#   'follow': 1,
#   'shouting': 1,
#   'together': 1,
#   'tipping': 1,
#   'hits': 1,
#   'behind': 1,
#   'reflect': 1,
#   'forward': 1,
#   'workers': 1,
#   'cutest': 1,
#   'began': 1,
#   'helped': 1,
#   'still': 1,
#   'person': 1,
#   'orchard': 1,
#   'presenting': 1,
#   'trusting': 1,
#   'made': 1,
#   'book': 1,
#   'coffee': 1,
#   'running': 1,
#   'enjoyed': 1,
#   'hailey': 1,
#   'pas': 1,
#   'cummings': 1,
#   'respect': 1,
#   'buen': 1,
#   'copy': 1,
#   'texan': 1,
#   'long': 1,
#   'dad': 1,
#   'fearless': 1,
#   'tip': 1,
#   'provided': 1,
#   'model': 1,
#   'congressional': 1,
#   'dog': 1,
#   'uplifter': 1,
#   'outside': 1,
#   'bartender': 1,
#   'link': 1,
#   'dinosaur': 1,
#   'tonight': 1,
#   'adding': 1,
#   'sarah': 1,
#   'early': 1,
#   'tireless': 1,
#   'greatness': 1,
#   'bringing': 1,
#   'accounts': 1,
#   'toolkits': 1,
#   'start': 1,
#   'united': 1,
#   'change': 1,
#   'th': 1,
#   'activist': 1,
#   'dollar': 1,
#   'alongside': 1,
#   'stay': 1,
#   'warm': 1,
#   'friendly': 1,
#   'meet': 1,
#   'half': 1,
#   'unimaginable': 1,
#   'valdez': 1,
#   'mine': 1,
#   'courageous': 1,
#   'apps': 1,
#   'tough': 1,
#   'contributed': 1,
#   'shamefully': 1,
#   'congrats': 1,
#   'totally': 1,
#   'fred': 1,
#   'listen': 1,
#   'additional': 1,
#   'money': 1,
#   'p': 1,
#   'incl': 1,
#   'father': 1,
#   'payments': 1,
#   'check': 1,
#   'hospitality': 1,
#   'padma': 1,
#   'wow': 1,
#   'due': 1,
#   'loss': 1,
#   'sunday': 1,
#   'arrived': 1,
#   'photo': 1,
#   'helpful': 1,
#   'generic': 1,
#   'deeply': 1,
#   'turning': 1,
#   'hell': 1,
#   'profound': 1,
#   'throw': 1,
#   'update': 1,
#   'lift': 1,
#   'show': 1,
#   'securing': 1,
#   'abortion': 1,
#   'magazine': 1,
#   'victory': 1,
#   'send': 1,
#   'hurricane': 1,
#   'masterful': 1,
#   'ago': 1,
#   'level': 1,
#   'commitment': 1,
#   'absolutely': 1,
#   'nice': 1,
#   'le': 1,
#   'historic': 1,
#   'drop': 1,
#   'columbine': 1,
#   'thursday': 1,
#   'american': 1,
#   'talk': 1,
#   'main': 1,
#   'donated': 1,
#   'available': 1,
#   'report': 1,
#   'survivor': 1,
#   'addition': 1,
#   'legislator': 1,
#   'wellness': 1,
#   'portal': 1,
#   'unwrapped': 1,
#   'gold': 1,
#   'morning': 1,
#   'excellence': 1,
#   'thankful': 1,
#   'successfully': 1,
#   'whatever': 1,
#   'award': 1,
#   'taíno': 1,
#   'census': 1,
#   'city': 1,
#   'protip': 1,
#   'past': 1,
#   'place': 1,
#   'tipo': 1,
#   'loved': 1,
#   'troop': 1,
#   'aoc': 1,
#   'part': 1,
#   'member': 1,
#   'holding': 1,
#   'investment': 1,
#   'pedestrian': 1,
#   'incredibly': 1,
#   'kurt': 1,
#   'found': 1,
#   'survived': 1,
#   'saying': 1,
#   'personal': 1,
#   'amplify': 1,
#   'consistently': 1,
#   'joining': 1,
#   'matters': 1,
#   'advocacy': 1,
#   'delivery': 1,
#   'showed': 1,
#   'texas': 1,
#   'instead': 1,
#   'vision': 1,
#   'restore': 1,
#   'annual': 1,
#   'disagree': 1,
#   'lent': 1,
#   'watch': 1,
#   'woman': 1,
#   'short': 1,
#   'earth': 1,
#   'away': 1,
#   'mace': 1,
#   'site': 1,
#   'twins': 1,
#   'disrespectful': 1,
#   'influence': 1,
#   'keeping': 1,
#   'st': 1,
#   'gem': 1,
#   'ground': 1,
#   'chair': 1,
#   'marriage': 1,
#   'go': 1,
#   'awesome': 1,
#   'birth': 1,
#   'never': 1,
#   'blown': 1,
#   'old': 1,
#   'trans': 1,
#   'since': 1,
#   'path': 1,
#   'puppy': 1,
#   'thousand': 1,
#   'aftermath': 1,
#   'houston': 1},
#  ('truth', 1): {'truth': 18,
#   'like': 16,
#   'team': 16,
#   'people': 13,
#   'join': 11,
#   'news': 10,
#   'fact': 10,
#   'misinformation': 9,
#   'right': 7,
#   'also': 7,
#   'campaign': 7,
#   'congress': 7,
#   'know': 7,
#   'tweet': 7,
#   'today': 7,
#   'make': 6,
#   'facebook': 6,
#   'twitter': 6,
#   'time': 6,
#   'public': 5,
#   'outlet': 5,
#   'issue': 5,
#   'thing': 5,
#   'story': 5,
#   'billionaire': 5,
#   'going': 5,
#   'call': 5,
#   'spread': 5,
#   'survivor': 5,
#   'http': 5,
#   'matter': 5,
#   'medium': 4,
#   'work': 4,
#   'around': 4,
#   'organizing': 4,
#   'week': 4,
#   'wing': 4,
#   'question': 4,
#   'want': 4,
#   'member': 4,
#   'saying': 4,
#   'political': 4,
#   'woman': 4,
#   'first': 3,
#   'help': 3,
#   'space': 3,
#   'private': 3,
#   'email': 3,
#   'sexual': 3,
#   'nixon': 3,
#   'remember': 3,
#   'organizer': 3,
#   'viral': 3,
#   'responsible': 3,
#   'journalist': 3,
#   'retweet': 3,
#   'thanks': 3,
#   'facts': 3,
#   'word': 3,
#   'without': 3,
#   'well': 3,
#   'grassroots': 3,
#   'sensitive': 3,
#   'come': 3,
#   'actually': 3,
#   'full': 3,
#   'tucker': 3,
#   'made': 3,
#   'covering': 3,
#   'ignore': 3,
#   'stay': 3,
#   'back': 3,
#   'money': 3,
#   'power': 3,
#   'need': 3,
#   'day': 3,
#   'info': 3,
#   'social': 3,
#   'violence': 3,
#   'said': 3,
#   'folk': 3,
#   'take': 3,
#   'platform': 3,
#   'look': 3,
#   'carlson': 3,
#   'since': 3,
#   'disinformation': 3,
#   'really': 3,
#   'one': 2,
#   'disclosure': 2,
#   'instagram': 2,
#   'whether': 2,
#   'dosomething': 2,
#   'remark': 2,
#   'election': 2,
#   'responsibility': 2,
#   'enough': 2,
#   'give': 2,
#   'clip': 2,
#   'note': 2,
#   'trading': 2,
#   'traction': 2,
#   'say': 2,
#   'another': 2,
#   'straight': 2,
#   'tripped': 2,
#   'fake': 2,
#   'lmao': 2,
#   'ever': 2,
#   'amazon': 2,
#   'lgbt': 2,
#   'anything': 2,
#   'free': 2,
#   'audience': 2,
#   'community': 2,
#   'pretty': 2,
#   'asked': 2,
#   'seem': 2,
#   'meanwhile': 2,
#   'propaganda': 2,
#   'thought': 2,
#   'politics': 2,
#   'understanding': 2,
#   'went': 2,
#   'high': 2,
#   'agree': 2,
#   'office': 2,
#   'working': 2,
#   'spanish': 2,
#   'even': 2,
#   'hope': 2,
#   'communication': 2,
#   'happens': 2,
#   'house': 2,
#   'policy': 2,
#   'care': 2,
#   'guilty': 2,
#   'worked': 2,
#   'assault': 2,
#   'keep': 2,
#   'last': 2,
#   'leading': 2,
#   'language': 2,
#   'address': 2,
#   'monopolistic': 2,
#   'republican': 2,
#   'account': 2,
#   'list': 2,
#   'death': 2,
#   'exposed': 2,
#   'demanding': 2,
#   'bad': 2,
#   'person': 2,
#   'control': 2,
#   'book': 2,
#   'moment': 2,
#   'helping': 2,
#   'would': 2,
#   'seriously': 2,
#   'shoe': 2,
#   'year': 2,
#   'harassment': 2,
#   'link': 2,
#   'threat': 2,
#   'mean': 2,
#   'idea': 2,
#   'happening': 2,
#   'record': 2,
#   'many': 2,
#   'th': 2,
#   'stop': 2,
#   'making': 2,
#   'using': 2,
#   'internet': 2,
#   'doe': 2,
#   'informed': 2,
#   'literally': 2,
#   'exactly': 2,
#   'press': 2,
#   'beltway': 2,
#   'photoshopped': 2,
#   'corporate': 2,
#   'english': 2,
#   'headline': 2,
#   'given': 2,
#   'tell': 2,
#   'ago': 2,
#   'regularly': 2,
#   'absolutely': 2,
#   'tired': 2,
#   'good': 2,
#   'targeting': 2,
#   'conversation': 2,
#   'fund': 2,
#   'aside': 2,
#   'national': 2,
#   'publish': 2,
#   'holding': 2,
#   'move': 2,
#   'stock': 2,
#   'extreme': 2,
#   'already': 2,
#   'night': 2,
#   'amount': 2,
#   'banned': 2,
#   'stress': 2,
#   'either': 2,
#   'gave': 2,
#   'food': 2,
#   'important': 2,
#   'belief': 2,
#   'hard': 2,
#   'happened': 2,
#   'turn': 1,
#   'claiming': 1,
#   'role': 1,
#   'damning': 1,
#   'uncomfortable': 1,
#   'chose': 1,
#   'reason': 1,
#   'sure': 1,
#   'collectively': 1,
#   'tv': 1,
#   'reading': 1,
#   'blaming': 1,
#   'leadonleave': 1,
#   'shame': 1,
#   'success': 1,
#   'co': 1,
#   'way': 1,
#   'genuinely': 1,
#   'journalism': 1,
#   'yesterday': 1,
#   'result': 1,
#   'misdeed': 1,
#   'purge': 1,
#   'capitalism': 1,
#   'leadership': 1,
#   'earlier': 1,
#   'e': 1,
#   'gossip': 1,
#   'led': 1,
#   'respected': 1,
#   'uprising': 1,
#   'independent': 1,
#   'concept': 1,
#   'lot': 1,
#   'hitting': 1,
#   'broadcasting': 1,
#   'piece': 1,
#   'wonder': 1,
#   'better': 1,
#   'implicated': 1,
#   'else': 1,
#   'toying': 1,
#   'cast': 1,
#   'verify': 1,
#   'phony': 1,
#   'squeezed': 1,
#   'abused': 1,
#   'group': 1,
#   'neither': 1,
#   'rationing': 1,
#   'career': 1,
#   'james': 1,
#   'locked': 1,
#   'meme': 1,
#   'retweets': 1,
#   'maneuvering': 1,
#   'fighting': 1,
#   'supporter': 1,
#   'conveniently': 1,
#   'worth': 1,
#   'human': 1,
#   'subscription': 1,
#   'deny': 1,
#   'received': 1,
#   'seconds': 1,
#   'read': 1,
#   'insecurity': 1,
#   'lighter': 1,
#   'weakens': 1,
#   'march': 1,
#   'lobbyist': 1,
#   'spend': 1,
#   'telling': 1,
#   'credibly': 1,
#   'constant': 1,
#   'questioned': 1,
#   'air': 1,
#   'price': 1,
#   'torrenting': 1,
#   'wondering': 1,
#   'moral': 1,
#   'clear': 1,
#   'yep': 1,
#   'tweeting': 1,
#   'dishonestly': 1,
#   'sleeping': 1,
#   'letter': 1,
#   'hill': 1,
#   'standing': 1,
#   'escalate': 1,
#   'fought': 1,
#   'expired': 1,
#   'sold': 1,
#   'bro': 1,
#   'deserve': 1,
#   'find': 1,
#   'counted': 1,
#   'whiners': 1,
#   'waiting': 1,
#   'feel': 1,
#   'brain': 1,
#   'europe': 1,
#   'continue': 1,
#   'inbox': 1,
#   'channel': 1,
#   'location': 1,
#   'pushed': 1,
#   'abuser': 1,
#   'staff': 1,
#   'polite': 1,
#   'agenda': 1,
#   'pleasure': 1,
#   'corrupt': 1,
#   'maybe': 1,
#   'stand': 1,
#   'carville': 1,
#   'aware': 1,
#   'showing': 1,
#   'actual': 1,
#   'openly': 1,
#   'circulating': 1,
#   'slur': 1,
#   'accelerated': 1,
#   'overreaction': 1,
#   'extraordinary': 1,
#   'chamber': 1,
#   'strengthens': 1,
#   'squash': 1,
#   'broader': 1,
#   'proving': 1,
#   'entire': 1,
#   'local': 1,
#   'extensive': 1,
#   'pressed': 1,
#   'delusion': 1,
#   'unchallenged': 1,
#   'problem': 1,
#   'dragging': 1,
#   'getting': 1,
#   'volume': 1,
#   'notch': 1,
#   'voice': 1,
#   'bought': 1,
#   'genuine': 1,
#   'worse': 1,
#   'confirming': 1,
#   'york': 1,
#   'act': 1,
#   'honest': 1,
#   'top': 1,
#   'google': 1,
#   'must': 1,
#   'hostage': 1,
#   'almost': 1,
#   'pablo': 1,
#   'whole': 1,
#   'became': 1,
#   'significant': 1,
#   'include': 1,
#   'protected': 1,
#   'ideology': 1,
#   'thank': 1,
#   'ovation': 1,
#   'phone': 1,
#   'cosponsor': 1,
#   'footage': 1,
#   'protect': 1,
#   'probably': 1,
#   'cuban': 1,
#   'analytica': 1,
#   'potential': 1,
#   'youtuber': 1,
#   'contribution': 1,
#   'throwing': 1,
#   'putting': 1,
#   'impulse': 1,
#   'embrace': 1,
#   'acknowledging': 1,
#   'learn': 1,
#   'secretly': 1,
#   'happy': 1,
#   'amplification': 1,
#   'exploding': 1,
#   'treating': 1,
#   'month': 1,
#   'scored': 1,
#   'company': 1,
#   'movement': 1,
#   'outcome': 1,
#   'ramp': 1,
#   'character': 1,
#   'official': 1,
#   'exploited': 1,
#   'racial': 1,
#   'healthy': 1,
#   'touch': 1,
#   'skill': 1,
#   'sent': 1,
#   'mandated': 1,
#   'event': 1,
#   'beloved': 1,
#   'floating': 1,
#   'creating': 1,
#   'timeline': 1,
#   'harder': 1,
#   'across': 1,
#   'fueled': 1,
#   'misinfo': 1,
#   'intervened': 1,
#   'loophole': 1,
#   'least': 1,
#   'crony': 1,
#   'predictable': 1,
#   'required': 1,
#   'covered': 1,
#   'mails': 1,
#   'answering': 1,
#   'information': 1,
#   'contacted': 1,
#   'newly': 1,
#   'crime': 1,
#   'pride': 1,
#   'security': 1,
#   'chain': 1,
#   'speech': 1,
#   'environment': 1,
#   'yacht': 1,
#   'development': 1,
#   'sell': 1,
#   'equity': 1,
#   'love': 1,
#   'review': 1,
#   'spoke': 1,
#   'easy': 1,
#   'party': 1,
#   'qanon': 1,
#   'newspaper': 1,
#   'preparation': 1,
#   'actonclimate': 1,
#   'happen': 1,
#   'accused': 1,
#   'massive': 1,
#   'concerning': 1,
#   'asks': 1,
#   'advice': 1,
#   'came': 1,
#   'aspersion': 1,
#   'bathroom': 1,
#   'point': 1,
#   'entitled': 1,
#   'asking': 1,
#   'accept': 1,
#   'vilification': 1,
#   'expose': 1,
#   'skews': 1,
#   'accountability': 1,
#   'decide': 1,
#   'contradicting': 1,
#   'approved': 1,
#   'someone': 1,
#   'random': 1,
#   'engage': 1,
#   'controversial': 1,
#   'trade': 1,
#   'sufficient': 1,
#   'trump': 1,
#   'much': 1,
#   'equate': 1,
#   'sourcing': 1,
#   'harassed': 1,
#   'post': 1,
#   'leader': 1,
#   'dude': 1,
#   'knuckle': 1,
#   'competition': 1,
#   'targeted': 1,
#   'honestly': 1,
#   'country': 1,
#   'places': 1,
#   'institutionally': 1,
#   'moderate': 1,
#   'delivered': 1,
#   'reminder': 1,
#   'credibility': 1,
#   'content': 1,
#   'support': 1,
#   'article': 1,
#   'hungry': 1,
#   'disclaimer': 1,
#   'media': 1,
#   'wish': 1,
#   'market': 1,
#   'statement': 1,
#   'cycle': 1,
#   'count': 1,
#   'think': 1,
#   'tried': 1,
#   'guest': 1,
#   'follow': 1,
#   'sometimes': 1,
#   'empower': 1,
#   'leaping': 1,
#   'speaker': 1,
#   'end': 1,
#   'tantrum': 1,
#   'consequence': 1,
#   'signed': 1,
#   'serious': 1,
#   'everyday': 1,
#   'exaggerating': 1,
#   'drama': 1,
#   'necessary': 1,
#   'forward': 1,
#   'plan': 1,
#   'discussion': 1,
#   'playing': 1,
#   'restaurant': 1,
#   'largely': 1,
#   'column': 1,
#   'live': 1,
#   'always': 1,
#   'discrediting': 1,
#   'action': 1,
#   'gifted': 1,
#   'however': 1,
#   'fyi': 1,
#   'proceeds': 1,
#   'equip': 1,
#   'reality': 1,
#   'pas': 1,
#   'including': 1,
#   'lady': 1,
#   'cardinal': 1,
#   'widely': 1,
#   'elected': 1,
#   'student': 1,
#   'reaping': 1,
#   'heel': 1,
#   'impact': 1,
#   'emerging': 1,
#   'tackle': 1,
#   'supporting': 1,
#   'game': 1,
#   'congressional': 1,
#   'young': 1,
#   'danger': 1,
#   'reporter': 1,
#   'veteran': 1,
#   'please': 1,
#   'bus': 1,
#   'staple': 1,
#   'generates': 1,
#   'benefit': 1,
#   'suggested': 1,
#   'tonight': 1,
#   'speak': 1,
#   'improve': 1,
#   'capitol': 1,
#   'cameron': 1,
#   'incite': 1,
#   'early': 1,
#   'latest': 1,
#   'ownership': 1,
#   'pharma': 1,
#   'bringing': 1,
#   'integrity': 1,
#   'pay': 1,
#   'upset': 1,
#   'document': 1,
#   'bubble': 1,
#   'esque': 1,
#   'dollar': 1,
#   'activist': 1,
#   'books': 1,
#   'censorship': 1,
#   'claim': 1,
#   'eventually': 1,
#   'rebrands': 1,
#   'posting': 1,
#   'held': 1,
#   'gathering': 1,
#   'fight': 1,
#   'newsroom': 1,
#   'huge': 1,
#   'hate': 1,
#   'colleague': 1,
#   'slapped': 1,
#   'protest': 1,
#   'valued': 1,
#   'stream': 1,
#   'key': 1,
#   'dime': 1,
#   'internalize': 1,
#   'commerce': 1,
#   'shocked': 1,
#   'equating': 1,
#   'check': 1,
#   'chopped': 1,
#   'trying': 1,
#   'gop': 1,
#   'watching': 1,
#   'extensively': 1,
#   'looked': 1,
#   'zuckerberg': 1,
#   'scared': 1,
#   'clicks': 1,
#   'anyone': 1,
#   'revealing': 1,
#   'vote': 1,
#   'sponsored': 1,
#   'floor': 1,
#   'politician': 1,
#   'wishing': 1,
#   'behavior': 1,
#   'every': 1,
#   'gross': 1,
#   'freedom': 1,
#   'jacket': 1,
#   'mission': 1,
#   'pressure': 1,
#   'throw': 1,
#   'unilaterally': 1,
#   'kremlin': 1,
#   'fueling': 1,
#   'played': 1,
#   'type': 1,
#   'thiel': 1,
#   'million': 1,
#   'challenged': 1,
#   'show': 1,
#   'insane': 1,
#   'nonprofit': 1,
#   'writing': 1,
#   'creep': 1,
#   'obsessive': 1,
#   'opinion': 1,
#   'tossed': 1,
#   'exhibit': 1,
#   'sick': 1,
#   'critic': 1,
#   'substantive': 1,
#   'prospect': 1,
#   'fascism': 1,
#   'grateful': 1,
#   'life': 1,
#   'tank': 1,
#   'dinner': 1,
#   'suspect': 1,
#   'proposal': 1,
#   'tweeted': 1,
#   'op': 1,
#   'insider': 1,
#   'attn': 1,
#   'touching': 1,
#   'special': 1,
#   'fully': 1,
#   'gutting': 1,
#   'likely': 1,
#   'answer': 1,
#   'anti': 1,
#   'access': 1,
#   'knew': 1,
#   'talk': 1,
#   'editor': 1,
#   'unsurprisingly': 1,
#   'mod': 1,
#   'release': 1,
#   'mo': 1,
#   'modeled': 1,
#   'distributed': 1,
#   'bipartisan': 1,
#   'peter': 1,
#   'others': 1,
#   'evaluate': 1,
#   'speechy': 1,
#   'dependent': 1,
#   'journalistic': 1,
#   'scammy': 1,
#   'attention': 1,
#   'monopoly': 1,
#   'reveal': 1,
#   'develop': 1,
#   'woke': 1,
#   'critical': 1,
#   'whatever': 1,
#   'fault': 1,
#   'underneath': 1,
#   'pundit': 1,
#   'clearly': 1,
#   'city': 1,
#   'effect': 1,
#   'number': 1,
#   'drowned': 1,
#   'repro': 1,
#   'belongs': 1,
#   'reported': 1,
#   'analyst': 1,
#   'skipping': 1,
#   'attack': 1,
#   'posted': 1,
#   'rushing': 1,
#   'hostile': 1,
#   'none': 1,
#   'shaping': 1,
#   'average': 1,
#   'whatsapp': 1,
#   'insinuation': 1,
#   'sympathy': 1,
#   'importance': 1,
#   'incredibly': 1,
#   'cancel': 1,
#   'gon': 1,
#   'large': 1,
#   'heat': 1,
#   'effort': 1,
#   'fear': 1,
#   'shout': 1,
#   'hypocritical': 1,
#   'individual': 1,
#   'represented': 1,
#   'source': 1,
#   'kessler': 1,
#   'harasser': 1,
#   'checked': 1,
#   'wildfire': 1,
#   'figures': 1,
#   'wade': 1,
#   'expense': 1,
#   'digging': 1,
#   'shameful': 1,
#   'took': 1,
#   'production': 1,
#   'texas': 1,
#   'created': 1,
#   'instead': 1,
#   'diali': 1,
#   'pumping': 1,
#   'yelling': 1,
#   'paper': 1,
#   'sellout': 1,
#   'investigation': 1,
#   'earnestly': 1,
#   'kid': 1,
#   'away': 1,
#   'testimony': 1,
#   'banning': 1,
#   'na': 1,
#   'false': 1,
#   'dispel': 1,
#   'lazily': 1,
#   'fleet': 1,
#   'several': 1,
#   'meltdown': 1,
#   'digital': 1,
#   'explosion': 1,
#   'demands': 1,
#   'approach': 1,
#   'cambridge': 1,
#   'see': 1,
#   'supposed': 1,
#   'despite': 1,
#   'nothing': 1,
#   'sense': 1,
#   'raped': 1,
#   'science': 1,
#   'easier': 1,
#   'nasty': 1,
#   'never': 1,
#   'analysis': 1,
#   'noise': 1,
#   'horrifying': 1},
#  ('biden', 2): {'biden': 109,
#   'president': 23,
#   'trump': 12,
#   'people': 10,
#   'economic': 8,
#   'admin': 8,
#   'right': 7,
#   'country': 7,
#   'election': 6,
#   'wage': 6,
#   'must': 6,
#   'elect': 6,
#   'want': 6,
#   'make': 5,
#   'working': 5,
#   'think': 5,
#   'let': 5,
#   'going': 5,
#   'progressive': 5,
#   'need': 5,
#   'million': 5,
#   'today': 5,
#   'family': 5,
#   'american': 5,
#   'joe': 5,
#   'like': 4,
#   'dems': 4,
#   'know': 4,
#   'policy': 4,
#   'long': 4,
#   'doc': 4,
#   'power': 4,
#   'crisis': 4,
#   'announced': 4,
#   'said': 4,
#   'time': 4,
#   'move': 4,
#   'take': 4,
#   'america': 3,
#   'yesterday': 3,
#   'called': 3,
#   'read': 3,
#   'work': 3,
#   'letter': 3,
#   'candidate': 3,
#   'stand': 3,
#   'vice': 3,
#   'democracy': 3,
#   'congress': 3,
#   'minimum': 3,
#   'even': 3,
#   'deal': 3,
#   'create': 3,
#   'could': 3,
#   'house': 3,
#   'assange': 3,
#   'week': 3,
#   'leader': 3,
#   'often': 3,
#   'attempt': 3,
#   'support': 3,
#   'provide': 3,
#   'together': 3,
#   'live': 3,
#   'mean': 3,
#   'united': 3,
#   'home': 3,
#   'great': 3,
#   'best': 3,
#   'check': 3,
#   'absolutely': 3,
#   'question': 3,
#   'hour': 3,
#   'secret': 3,
#   'classified': 3,
#   'major': 3,
#   'leave': 3,
#   'nation': 3,
#   'one': 2,
#   'sure': 2,
#   'strong': 2,
#   'whether': 2,
#   'facing': 2,
#   'leadership': 2,
#   'hr': 2,
#   'enough': 2,
#   'give': 2,
#   'hunter': 2,
#   'rally': 2,
#   'first': 2,
#   'though': 2,
#   'fighting': 2,
#   'also': 2,
#   'supporter': 2,
#   'human': 2,
#   'say': 2,
#   'done': 2,
#   'justice': 2,
#   'help': 2,
#   'world': 2,
#   'relief': 2,
#   'clear': 2,
#   'outlet': 2,
#   'bring': 2,
#   'campaign': 2,
#   'federal': 2,
#   'keystone': 2,
#   'agenda': 2,
#   'ability': 2,
#   'meekly': 2,
#   'mishandling': 2,
#   'democrat': 2,
#   'economy': 2,
#   'around': 2,
#   'senate': 2,
#   'completely': 2,
#   'climate': 2,
#   'states': 2,
#   'limit': 2,
#   'happy': 2,
#   'agree': 2,
#   'movement': 2,
#   'begin': 2,
#   'defeat': 2,
#   'debt': 2,
#   'least': 2,
#   'job': 2,
#   'speech': 2,
#   'speaking': 2,
#   'conservative': 2,
#   'keep': 2,
#   'beginning': 2,
#   'nevada': 2,
#   'starvation': 2,
#   'repeated': 2,
#   'decision': 2,
#   'value': 2,
#   'republican': 2,
#   'executive': 2,
#   'forward': 2,
#   'full': 2,
#   'caucus': 2,
#   'would': 2,
#   'elected': 2,
#   'student': 2,
#   'bernie': 2,
#   'democratic': 2,
#   'supporting': 2,
#   'allow': 2,
#   'believe': 2,
#   'worker': 2,
#   'news': 2,
#   'income': 2,
#   'demand': 2,
#   'document': 2,
#   'many': 2,
#   'claim': 2,
#   'fight': 2,
#   'doe': 2,
#   'vote': 2,
#   'government': 2,
#   'exactly': 2,
#   'families': 2,
#   'russian': 2,
#   'victory': 2,
#   'proposal': 2,
#   'le': 2,
#   'years': 2,
#   'understands': 2,
#   'attack': 2,
#   'place': 2,
#   'field': 2,
#   'birthday': 2,
#   'promised': 2,
#   'already': 2,
#   'order': 2,
#   'investigation': 2,
#   'difference': 2,
#   'offer': 2,
#   'bigoted': 2,
#   'look': 2,
#   'paid': 2,
#   'since': 2,
#   'worst': 2,
#   'disinformation': 2,
#   'medium': 1,
#   'basic': 1,
#   'reps': 1,
#   'equal': 1,
#   'diplomacy': 1,
#   'role': 1,
#   'similar': 1,
#   'chose': 1,
#   'reducing': 1,
#   'reason': 1,
#   'secrets': 1,
#   'progressives': 1,
#   'debate': 1,
#   'refusal': 1,
#   'blaming': 1,
#   'slammed': 1,
#   'provision': 1,
#   'known': 1,
#   'kellogg': 1,
#   'hilarious': 1,
#   'object': 1,
#   'state': 1,
#   'way': 1,
#   'cocaine': 1,
#   'younger': 1,
#   'living': 1,
#   'accord': 1,
#   'imprecise': 1,
#   'result': 1,
#   'involved': 1,
#   'factory': 1,
#   'public': 1,
#   'earlier': 1,
#   'finally': 1,
#   'looking': 1,
#   'abandoned': 1,
#   'constitution': 1,
#   'tribute': 1,
#   'declassify': 1,
#   'lot': 1,
#   'might': 1,
#   'onto': 1,
#   'better': 1,
#   'ways': 1,
#   'pipeline': 1,
#   'introduce': 1,
#   'transition': 1,
#   'buttered': 1,
#   'abroad': 1,
#   'raise': 1,
#   'sister': 1,
#   'discus': 1,
#   'breaking': 1,
#   'group': 1,
#   'offensive': 1,
#   'xenophobic': 1,
#   'authority': 1,
#   'sound': 1,
#   'ohio': 1,
#   'felony': 1,
#   'cut': 1,
#   'sleepyted': 1,
#   'feed': 1,
#   'pant': 1,
#   'profit': 1,
#   'join': 1,
#   'feeding': 1,
#   'hand': 1,
#   'concern': 1,
#   'delaying': 1,
#   'posture': 1,
#   'park': 1,
#   'credibly': 1,
#   'constant': 1,
#   'manchin': 1,
#   'questioned': 1,
#   'navy': 1,
#   'lean': 1,
#   'cruz': 1,
#   'tool': 1,
#   'render': 1,
#   'mitt': 1,
#   'asleep': 1,
#   'expectation': 1,
#   'insufficient': 1,
#   'winning': 1,
#   'sleeping': 1,
#   'worry': 1,
#   'overwhelming': 1,
#   'bury': 1,
#   'fought': 1,
#   'pressured': 1,
#   'three': 1,
#   'indisputably': 1,
#   'fake': 1,
#   'cheered': 1,
#   'separate': 1,
#   'fetterman': 1,
#   'tune': 1,
#   'determine': 1,
#   'find': 1,
#   'crimes': 1,
#   'undisclosed': 1,
#   'minutes': 1,
#   'govern': 1,
#   'coherent': 1,
#   'spreading': 1,
#   'electing': 1,
#   'lie': 1,
#   'super': 1,
#   'overstated': 1,
#   'permit': 1,
#   'rule': 1,
#   'side': 1,
#   'obama': 1,
#   'hoping': 1,
#   'amazon': 1,
#   'correct': 1,
#   'quite': 1,
#   'try': 1,
#   'absurd': 1,
#   'course': 1,
#   'alive': 1,
#   'defeating': 1,
#   'acknowledge': 1,
#   'performance': 1,
#   'observations': 1,
#   'campaigned': 1,
#   'suppress': 1,
#   'motif': 1,
#   'sudden': 1,
#   'improper': 1,
#   'leaders': 1,
#   'stutter': 1,
#   'requesting': 1,
#   'anybody': 1,
#   'pigeons': 1,
#   'drug': 1,
#   'free': 1,
#   'string': 1,
#   'pursue': 1,
#   'almost': 1,
#   'breath': 1,
#   'archive': 1,
#   'remember': 1,
#   'enact': 1,
#   'became': 1,
#   'include': 1,
#   'inflation': 1,
#   'sentence': 1,
#   'thank': 1,
#   'medicare': 1,
#   'depression': 1,
#   'medical': 1,
#   'prescription': 1,
#   'organizer': 1,
#   'protect': 1,
#   'forgiving': 1,
#   'inherit': 1,
#   'describing': 1,
#   'equitable': 1,
#   'thought': 1,
#   'sitting': 1,
#   'critiqued': 1,
#   'politics': 1,
#   'upholding': 1,
#   'thread': 1,
#   'small': 1,
#   'responsible': 1,
#   'condolence': 1,
#   'office': 1,
#   'final': 1,
#   'grounds': 1,
#   'wearing': 1,
#   'us': 1,
#   'duss': 1,
#   'welcome': 1,
#   'immigrant': 1,
#   'protesting': 1,
#   'decency': 1,
#   'struggling': 1,
#   'disaster': 1,
#   'speaks': 1,
#   'alternative': 1,
#   'based': 1,
#   'secretary': 1,
#   'persecution': 1,
#   'across': 1,
#   'declared': 1,
#   'divorce': 1,
#   'maddow': 1,
#   'thanks': 1,
#   'guy': 1,
#   'crime': 1,
#   'care': 1,
#   'appears': 1,
#   'security': 1,
#   'responding': 1,
#   'love': 1,
#   'dnc': 1,
#   'prison': 1,
#   'temperament': 1,
#   'foster': 1,
#   'advice': 1,
#   'came': 1,
#   'remove': 1,
#   'refusing': 1,
#   'greed': 1,
#   'issue': 1,
#   'left': 1,
#   'jesse': 1,
#   'sacrifice': 1,
#   'anyway': 1,
#   'delivering': 1,
#   'singal': 1,
#   'congratulation': 1,
#   'voting': 1,
#   'last': 1,
#   'setting': 1,
#   'grave': 1,
#   'reporting': 1,
#   'impeached': 1,
#   'goal': 1,
#   'word': 1,
#   'line': 1,
#   'appear': 1,
#   'australia': 1,
#   'ready': 1,
#   'scientist': 1,
#   'sexiest': 1,
#   'post': 1,
#   'putin': 1,
#   'beating': 1,
#   'golf': 1,
#   'race': 1,
#   'testament': 1,
#   'win': 1,
#   'kind': 1,
#   'doyourjob': 1,
#   'except': 1,
#   'build': 1,
#   'utterly': 1,
#   'praising': 1,
#   'deferentially': 1,
#   'express': 1,
#   'comeback': 1,
#   'royal': 1,
#   'leading': 1,
#   'unclear': 1,
#   'compromised': 1,
#   'little': 1,
#   'loveislove': 1,
#   'address': 1,
#   'spin': 1,
#   'containing': 1,
#   'unlimited': 1,
#   'blob': 1,
#   'enraged': 1,
#   'college': 1,
#   'cycle': 1,
#   'whereas': 1,
#   'sen': 1,
#   'fell': 1,
#   'count': 1,
#   'seen': 1,
#   'sensitive': 1,
#   'file': 1,
#   'come': 1,
#   'follow': 1,
#   'lecture': 1,
#   'immigration': 1,
#   'consequence': 1,
#   'fringe': 1,
#   'handled': 1,
#   'used': 1,
#   'wife': 1,
#   'endless': 1,
#   'inclusive': 1,
#   'connection': 1,
#   'playing': 1,
#   'decade': 1,
#   'brother': 1,
#   'mask': 1,
#   'actively': 1,
#   'paths': 1,
#   'ousted': 1,
#   'always': 1,
#   'still': 1,
#   'action': 1,
#   'person': 1,
#   'made': 1,
#   'running': 1,
#   'understand': 1,
#   'committed': 1,
#   'pas': 1,
#   'including': 1,
#   'creek': 1,
#   'respect': 1,
#   'payment': 1,
#   'govt': 1,
#   'opposition': 1,
#   'tricky': 1,
#   'vetoed': 1,
#   'russia': 1,
#   'call': 1,
#   'seems': 1,
#   'brazil': 1,
#   'pompeo': 1,
#   'young': 1,
#   'reporter': 1,
#   'discourse': 1,
#   'defense': 1,
#   'year': 1,
#   'eligibility': 1,
#   'generous': 1,
#   'unable': 1,
#   'china': 1,
#   'romney': 1,
#   'tonight': 1,
#   'tuition': 1,
#   'administration': 1,
#   'respond': 1,
#   'boldness': 1,
#   'billion': 1,
#   'international': 1,
#   'idea': 1,
#   'receive': 1,
#   'doubt': 1,
#   'fewer': 1,
#   'happening': 1,
#   'kamala': 1,
#   'struggle': 1,
#   'ukrainian': 1,
#   'spread': 1,
#   'adopt': 1,
#   'toward': 1,
#   'bench': 1,
#   'jobs': 1,
#   'alone': 1,
#   'held': 1,
#   'dozen': 1,
#   'expecting': 1,
#   'issued': 1,
#   'colleague': 1,
#   'break': 1,
#   'btwn': 1,
#   'aspect': 1,
#   'improperly': 1,
#   'racist': 1,
#   'term': 1,
#   'disciplined': 1,
#   'department': 1,
#   'glove': 1,
#   'risk': 1,
#   'back': 1,
#   'begrudgingly': 1,
#   'protest': 1,
#   'schoolchild': 1,
#   'julian': 1,
#   'starting': 1,
#   'headquarters': 1,
#   'case': 1,
#   'told': 1,
#   'equality': 1,
#   'father': 1,
#   'real': 1,
#   'trying': 1,
#   'delete': 1,
#   'difficult': 1,
#   'loan': 1,
#   'decided': 1,
#   'anyone': 1,
#   'day': 1,
#   'town': 1,
#   'dangerous': 1,
#   'second': 1,
#   'thinking': 1,
#   'format': 1,
#   'politician': 1,
#   'bbb': 1,
#   'remains': 1,
#   'every': 1,
#   'rejoining': 1,
#   'promise': 1,
#   'wa': 1,
#   'ceasefire': 1,
#   'played': 1,
#   'hold': 1,
#   'corporate': 1,
#   'english': 1,
#   'memo': 1,
#   'grateful': 1,
#   'life': 1,
#   'garage': 1,
#   'examine': 1,
#   'undermine': 1,
#   'tweet': 1,
#   'enormous': 1,
#   'deliver': 1,
#   'ago': 1,
#   'voted': 1,
#   'imprisoned': 1,
#   'normal': 1,
#   'commitment': 1,
#   'interference': 1,
#   'passed': 1,
#   'far': 1,
#   'wo': 1,
#   'retracted': 1,
#   'answer': 1,
#   'drop': 1,
#   'access': 1,
#   'soccer': 1,
#   'guardian': 1,
#   'unacceptable': 1,
#   'good': 1,
#   'dealing': 1,
#   'disturbing': 1,
#   'virus': 1,
#   'morning': 1,
#   'fact': 1,
#   'semi': 1,
#   'thankful': 1,
#   'echo': 1,
#   'class': 1,
#   'paris': 1,
#   'battle': 1,
#   'develop': 1,
#   'trial': 1,
#   'staffer': 1,
#   'whatever': 1,
#   'fault': 1,
#   'ally': 1,
#   'http': 1,
#   'toomey': 1,
#   'number': 1,
#   'rebuilding': 1,
#   'outright': 1,
#   'precedent': 1,
#   'belongs': 1,
#   'war': 1,
#   'national': 1,
#   'western': 1,
#   'usual': 1,
#   'part': 1,
#   'member': 1,
#   'pandemic': 1,
#   'peru': 1,
#   'presidential': 1,
#   'demconvention': 1,
#   'politico': 1,
#   'response': 1,
#   'simply': 1,
#   'cognitive': 1,
#   'cancel': 1,
#   'investigating': 1,
#   'found': 1,
#   'issues': 1,
#   'large': 1,
#   'bidding': 1,
#   'bread': 1,
#   'contrition': 1,
#   'covid': 1,
#   'hall': 1,
#   'business': 1,
#   'possible': 1,
#   'countless': 1,
#   'resembles': 1,
#   'quoting': 1,
#   'soil': 1,
#   'multiple': 1,
#   'striking': 1,
#   'visit': 1,
#   'masks': 1,
#   'spokesperson': 1,
#   'sends': 1,
#   'production': 1,
#   'intend': 1,
#   'save': 1,
#   'night': 1,
#   'instead': 1,
#   'political': 1,
#   'ballot': 1,
#   'disagree': 1,
#   'amount': 1,
#   'establishment': 1,
#   'earth': 1,
#   'compare': 1,
#   'away': 1,
#   'tactic': 1,
#   'foreign': 1,
#   'rent': 1,
#   'south': 1,
#   'influence': 1,
#   'sizes': 1,
#   'bill': 1,
#   'important': 1,
#   'wording': 1,
#   'wait': 1,
#   'underutilizing': 1,
#   'renounced': 1,
#   'next': 1,
#   'marriage': 1,
#   'delighted': 1,
#   'score': 1,
#   'despite': 1,
#   'sense': 1,
#   'embarrassment': 1,
#   'hard': 1,
#   'ahead': 1,
#   'cost': 1,
#   'recklessly': 1,
#   'analysis': 1,
#   'officially': 1,
#   'wokeness': 1,
#   'increasingly': 1,
#   'path': 1,
#   'donald': 1,
#   'disseminated': 1,
#   'really': 1},
#  ('people', 3): {'people': 9,
#   'fact': 9,
#   'many': 6,
#   'time': 6,
#   'woman': 6,
#   'read': 5,
#   'know': 5,
#   'someone': 5,
#   'actually': 5,
#   'would': 5,
#   'every': 5,
#   'never': 5,
#   'like': 4,
#   'even': 4,
#   'thing': 4,
#   'still': 4,
#   'person': 4,
#   'folk': 4,
#   'instead': 4,
#   'reason': 3,
#   'first': 3,
#   'right': 3,
#   'though': 3,
#   'work': 3,
#   'funny': 3,
#   'remember': 3,
#   'everyone': 3,
#   'word': 3,
#   'hear': 3,
#   'sometimes': 3,
#   'sorry': 3,
#   'real': 3,
#   'everything': 3,
#   'family': 3,
#   'others': 3,
#   'want': 3,
#   'menstruate': 3,
#   'okay': 2,
#   'whose': 2,
#   'bible': 2,
#   'fighting': 2,
#   'also': 2,
#   'world': 2,
#   'child': 2,
#   'rule': 2,
#   'side': 2,
#   'responded': 2,
#   'community': 2,
#   'thank': 2,
#   'designed': 2,
#   'thought': 2,
#   'syndrome': 2,
#   'heart': 2,
#   'complex': 2,
#   'across': 2,
#   'happens': 2,
#   'point': 2,
#   'baby': 2,
#   'true': 2,
#   'institution': 2,
#   'much': 2,
#   'well': 2,
#   'statement': 2,
#   'let': 2,
#   'full': 2,
#   'book': 2,
#   'believe': 2,
#   'treat': 2,
#   'start': 2,
#   'shot': 2,
#   'break': 2,
#   'check': 2,
#   'decided': 2,
#   'need': 2,
#   'anyone': 2,
#   'second': 2,
#   'protecting': 2,
#   'abuela': 2,
#   'life': 2,
#   'tell': 2,
#   'timestamp': 2,
#   'question': 2,
#   'conversation': 2,
#   'part': 2,
#   'imagine': 2,
#   'imposter': 2,
#   'uterus': 2,
#   'saying': 2,
#   'take': 2,
#   'banned': 2,
#   'either': 2,
#   'adult': 2,
#   'nothing': 2,
#   'worst': 2,
#   'talking': 2,
#   'convo': 1,
#   'medium': 1,
#   'turn': 1,
#   'role': 1,
#   'one': 1,
#   'step': 1,
#   'values': 1,
#   'optional': 1,
#   'way': 1,
#   'living': 1,
#   'strike': 1,
#   'leadership': 1,
#   'minting': 1,
#   'border': 1,
#   'enough': 1,
#   'give': 1,
#   'message': 1,
#   'invader': 1,
#   'concept': 1,
#   'lot': 1,
#   'inferiority': 1,
#   'linked': 1,
#   'workplace': 1,
#   'called': 1,
#   'green': 1,
#   'better': 1,
#   'absolute': 1,
#   'clip': 1,
#   'suffer': 1,
#   'else': 1,
#   'discus': 1,
#   'referred': 1,
#   'wild': 1,
#   'devastation': 1,
#   'reposted': 1,
#   'man': 1,
#   'nap': 1,
#   'exposure': 1,
#   'sriracha': 1,
#   'gen': 1,
#   'determining': 1,
#   'reaction': 1,
#   'yang': 1,
#   'say': 1,
#   'done': 1,
#   'addressed': 1,
#   'harm': 1,
#   'reduced': 1,
#   'kevin': 1,
#   'another': 1,
#   'liked': 1,
#   'handle': 1,
#   'truly': 1,
#   'telling': 1,
#   'four': 1,
#   'clear': 1,
#   'yep': 1,
#   'bring': 1,
#   'nowadays': 1,
#   'worry': 1,
#   'willing': 1,
#   'astoria': 1,
#   'detail': 1,
#   'alternate': 1,
#   'qualification': 1,
#   'ripping': 1,
#   'fired': 1,
#   'appreciate': 1,
#   'abbott': 1,
#   'maybe': 1,
#   'showing': 1,
#   'king': 1,
#   'learned': 1,
#   'island': 1,
#   'performance': 1,
#   'experienced': 1,
#   'getting': 1,
#   'evoked': 1,
#   'subject': 1,
#   'scene': 1,
#   'sort': 1,
#   'everybody': 1,
#   'whole': 1,
#   'underestimate': 1,
#   'heard': 1,
#   'around': 1,
#   'killing': 1,
#   'audio': 1,
#   'pointed': 1,
#   'hey': 1,
#   'crave': 1,
#   'pretty': 1,
#   'meanwhile': 1,
#   'flower': 1,
#   'bronx': 1,
#   'constituent': 1,
#   'objective': 1,
#   'completely': 1,
#   'functioning': 1,
#   'disappointing': 1,
#   'operation': 1,
#   'system': 1,
#   'heartbreak': 1,
#   'attempted': 1,
#   'went': 1,
#   'violent': 1,
#   'lead': 1,
#   'sight': 1,
#   'cc': 1,
#   'stove': 1,
#   'emotional': 1,
#   'trigonometry': 1,
#   'certain': 1,
#   'giving': 1,
#   'caution': 1,
#   'deal': 1,
#   'event': 1,
#   'timeline': 1,
#   'least': 1,
#   'house': 1,
#   'predictable': 1,
#   'thanks': 1,
#   'policy': 1,
#   'direction': 1,
#   'care': 1,
#   'bouquet': 1,
#   'thumping': 1,
#   'development': 1,
#   'arrive': 1,
#   'declaration': 1,
#   'aggressively': 1,
#   'taken': 1,
#   'glad': 1,
#   'massive': 1,
#   'compound': 1,
#   'worked': 1,
#   'tear': 1,
#   'regarding': 1,
#   'assault': 1,
#   'left': 1,
#   'issue': 1,
#   'engages': 1,
#   'avoid': 1,
#   'asking': 1,
#   'additionally': 1,
#   'beyond': 1,
#   'witnessing': 1,
#   'edge': 1,
#   'lost': 1,
#   'last': 1,
#   'daughter': 1,
#   'without': 1,
#   'plot': 1,
#   'raised': 1,
#   'school': 1,
#   'representative': 1,
#   'menstruating': 1,
#   'win': 1,
#   'incorrect': 1,
#   'utterly': 1,
#   'story': 1,
#   'studied': 1,
#   'support': 1,
#   'reasonable': 1,
#   'sync': 1,
#   'sunrise': 1,
#   'dylan': 1,
#   'open': 1,
#   'deep': 1,
#   'desired': 1,
#   'think': 1,
#   'come': 1,
#   'follow': 1,
#   'labor': 1,
#   'seek': 1,
#   'condition': 1,
#   'cancelstudentdebt': 1,
#   'behind': 1,
#   'chest': 1,
#   'felt': 1,
#   'tree': 1,
#   'sauce': 1,
#   'plan': 1,
#   'ramadan': 1,
#   'mask': 1,
#   'sotu': 1,
#   'always': 1,
#   'running': 1,
#   'front': 1,
#   'going': 1,
#   'lady': 1,
#   'pardon': 1,
#   'quote': 1,
#   'encounter': 1,
#   'student': 1,
#   'building': 1,
#   'dad': 1,
#   'questioning': 1,
#   'seems': 1,
#   'clickbait': 1,
#   'counsel': 1,
#   'young': 1,
#   'friend': 1,
#   'seeking': 1,
#   'medicine': 1,
#   'continues': 1,
#   'pretend': 1,
#   'coup': 1,
#   'year': 1,
#   'news': 1,
#   'confrontation': 1,
#   'sarah': 1,
#   'early': 1,
#   'idea': 1,
#   'happening': 1,
#   'download': 1,
#   'upset': 1,
#   'record': 1,
#   'valuable': 1,
#   'change': 1,
#   'th': 1,
#   'patriarchal': 1,
#   'larger': 1,
#   'claim': 1,
#   'walk': 1,
#   'alone': 1,
#   'mine': 1,
#   'rican': 1,
#   'aspect': 1,
#   'waiter': 1,
#   'cared': 1,
#   'share': 1,
#   'jack': 1,
#   'case': 1,
#   'binary': 1,
#   'deaf': 1,
#   'chopped': 1,
#   'trying': 1,
#   'caring': 1,
#   'gop': 1,
#   'something': 1,
#   'desantis': 1,
#   'newcomer': 1,
#   'stop': 1,
#   'gun': 1,
#   'wow': 1,
#   'gutted': 1,
#   'wise': 1,
#   'day': 1,
#   'ongoing': 1,
#   'dangerous': 1,
#   'negativity': 1,
#   'floor': 1,
#   'literally': 1,
#   'men': 1,
#   'sending': 1,
#   'show': 1,
#   'hold': 1,
#   'parking': 1,
#   'connect': 1,
#   'given': 1,
#   'inch': 1,
#   'ripped': 1,
#   'today': 1,
#   'throttle': 1,
#   'astounding': 1,
#   'absolutely': 1,
#   'christmas': 1,
#   'acted': 1,
#   'got': 1,
#   'differently': 1,
#   'hardworking': 1,
#   'gutting': 1,
#   'le': 1,
#   'answer': 1,
#   'holders': 1,
#   'letting': 1,
#   'talk': 1,
#   'snack': 1,
#   'common': 1,
#   'survivor': 1,
#   'reminiscing': 1,
#   'ta': 1,
#   'calc': 1,
#   'hour': 1,
#   'morning': 1,
#   'distorts': 1,
#   'handey': 1,
#   'attention': 1,
#   'clearly': 1,
#   'protip': 1,
#   'toddler': 1,
#   'place': 1,
#   'detractor': 1,
#   'none': 1,
#   'matter': 1,
#   'curved': 1,
#   'vividly': 1,
#   'simply': 1,
#   'misperception': 1,
#   'cognitive': 1,
#   'nominee': 1,
#   'underscore': 1,
#   'grief': 1,
#   'cage': 1,
#   'possible': 1,
#   'basically': 1,
#   'wade': 1,
#   'shameful': 1,
#   'already': 1,
#   'incredible': 1,
#   'imperils': 1,
#   'yelling': 1,
#   'bilal': 1,
#   'disconnect': 1,
#   'sex': 1,
#   'qualified': 1,
#   'single': 1,
#   'shamble': 1,
#   'mace': 1,
#   'pre': 1,
#   'factor': 1,
#   'mccarthy': 1,
#   'st': 1,
#   'approach': 1,
#   'see': 1,
#   'next': 1,
#   'puerto': 1,
#   'go': 1,
#   'example': 1,
#   'sense': 1,
#   'non': 1,
#   'gender': 1,
#   'warms': 1,
#   'forth': 1,
#   'context': 1,
#   'picture': 1,
#   'energy': 1,
#   'wrong': 1,
#   'palin': 1,
#   'trans': 1,
#   'careless': 1,
#   'date': 1,
#   'happened': 1,
#   'perfect': 1,
#   'thousand': 1,
#   'really': 1},
#  ('black', 4): {'black': 28,
#   'white': 19,
#   'people': 18,
#   'racist': 16,
#   'justice': 13,
#   'community': 13,
#   'racial': 13,
#   'color': 13,
#   'racism': 11,
#   'president': 10,
#   'right': 9,
#   'history': 8,
#   'working': 8,
#   'country': 8,
#   'many': 8,
#   'woman': 8,
#   'must': 7,
#   'supremacist': 7,
#   'worker': 7,
#   'need': 7,
#   'life': 7,
#   'american': 7,
#   'time': 7,
#   'latino': 7,
#   'economic': 6,
#   'make': 6,
#   'obama': 6,
#   'immigrant': 6,
#   'trump': 6,
#   'today': 6,
#   'class': 6,
#   'like': 5,
#   'state': 5,
#   'election': 5,
#   'work': 5,
#   'society': 5,
#   'stand': 5,
#   'king': 5,
#   'across': 5,
#   'house': 5,
#   'voting': 5,
#   'injustice': 5,
#   'family': 5,
#   'criminal': 4,
#   'wage': 4,
#   'know': 4,
#   'system': 4,
#   'movement': 4,
#   'crime': 4,
#   'naacp': 4,
#   'supremacy': 4,
#   'would': 4,
#   'young': 4,
#   'change': 4,
#   'fight': 4,
#   'police': 4,
#   'progressive': 4,
#   'likely': 4,
#   'violence': 4,
#   'political': 4,
#   'america': 3,
#   'convention': 3,
#   'asian': 3,
#   'opportunity': 3,
#   'first': 3,
#   'jackson': 3,
#   'join': 3,
#   'tune': 3,
#   'structural': 3,
#   'problem': 3,
#   'martin': 3,
#   'raising': 3,
#   'minimum': 3,
#   'tomato': 3,
#   'inspired': 3,
#   'last': 3,
#   'leader': 3,
#   'win': 3,
#   'civil': 3,
#   'support': 3,
#   'republican': 3,
#   'tried': 3,
#   'together': 3,
#   'live': 3,
#   'going': 3,
#   'tonight': 3,
#   'trying': 3,
#   'dangerous': 3,
#   'hour': 3,
#   'mountain': 3,
#   'attack': 3,
#   'place': 3,
#   'want': 3,
#   'member': 3,
#   'pandemic': 3,
#   'move': 3,
#   'forget': 3,
#   'jewish': 3,
#   'never': 3,
#   'resign': 3,
#   'step': 2,
#   'reason': 2,
#   'blue': 2,
#   'satisfied': 2,
#   'addressing': 2,
#   'confederacy': 2,
#   'result': 2,
#   'leadership': 2,
#   'transform': 2,
#   'holocaust': 2,
#   'attorney': 2,
#   'safety': 2,
#   'wild': 2,
#   'throughout': 2,
#   'higher': 2,
#   'legacy': 2,
#   'deny': 2,
#   'court': 2,
#   'another': 2,
#   'manchin': 2,
#   'suddenly': 2,
#   'child': 2,
#   'clear': 2,
#   'summer': 2,
#   'memphis': 2,
#   'standing': 2,
#   'disgrace': 2,
#   'candidate': 2,
#   'boy': 2,
#   'cannabis': 2,
#   'york': 2,
#   'around': 2,
#   'radical': 2,
#   'protect': 2,
#   'politics': 2,
#   'high': 2,
#   'challenge': 2,
#   'month': 2,
#   'office': 2,
#   'even': 2,
#   'exploited': 2,
#   'african': 2,
#   'judge': 2,
#   'policy': 2,
#   'assassinated': 2,
#   'overturn': 2,
#   'party': 2,
#   'issue': 2,
#   'embarrassing': 2,
#   'percent': 2,
#   'hear': 2,
#   'line': 2,
#   'without': 2,
#   'considered': 2,
#   'race': 2,
#   'build': 2,
#   'sen': 2,
#   'seen': 2,
#   'think': 2,
#   'come': 2,
#   'majority': 2,
#   'wealth': 2,
#   'condition': 2,
#   'supreme': 2,
#   'systemic': 2,
#   'helped': 2,
#   'generation': 2,
#   'person': 2,
#   'session': 2,
#   'front': 2,
#   'widely': 2,
#   'call': 2,
#   'democratic': 2,
#   'impact': 2,
#   'year': 2,
#   'mean': 2,
#   'emerged': 2,
#   'th': 2,
#   'activist': 2,
#   'hate': 2,
#   'colleague': 2,
#   'owned': 2,
#   'teaching': 2,
#   'equality': 2,
#   'luther': 2,
#   'power': 2,
#   'dignity': 2,
#   'loan': 2,
#   'day': 2,
#   'crisis': 2,
#   'vote': 2,
#   'built': 2,
#   'every': 2,
#   'bigotry': 2,
#   'million': 2,
#   'insurrection': 2,
#   'show': 2,
#   'hold': 2,
#   'rights': 2,
#   'root': 2,
#   'diverse': 2,
#   'gutting': 2,
#   'le': 2,
#   'celebrate': 2,
#   'common': 2,
#   'sanitation': 2,
#   'disgusting': 2,
#   'others': 2,
#   'conversation': 2,
#   'critical': 2,
#   'http': 2,
#   'city': 2,
#   'national': 2,
#   'matter': 2,
#   'folk': 2,
#   'take': 2,
#   'night': 2,
#   'team': 2,
#   'district': 2,
#   'watch': 2,
#   'single': 2,
#   'background': 2,
#   'look': 2,
#   'nation': 2,
#   'denial': 2,
#   'donald': 2,
#   'suspension': 1,
#   'convo': 1,
#   'pac': 1,
#   'participating': 1,
#   'one': 1,
#   'role': 1,
#   'bluer': 1,
#   'significantly': 1,
#   'brown': 1,
#   'virtual': 1,
#   'deliberately': 1,
#   'frisked': 1,
#   'safe': 1,
#   'debate': 1,
#   'legislature': 1,
#   'opposite': 1,
#   'indicative': 1,
#   'walton': 1,
#   'along': 1,
#   'cabinet': 1,
#   'known': 1,
#   'rant': 1,
#   'breonna': 1,
#   'exists': 1,
#   'remark': 1,
#   'living': 1,
#   'neighbor': 1,
#   'religion': 1,
#   'hurt': 1,
#   'public': 1,
#   'border': 1,
#   'finally': 1,
#   'enough': 1,
#   'pro': 1,
#   'independent': 1,
#   'abuse': 1,
#   'piece': 1,
#   'called': 1,
#   'comparing': 1,
#   'defeated': 1,
#   'webinar': 1,
#   'separation': 1,
#   'amendment': 1,
#   'discus': 1,
#   'group': 1,
#   'rosa': 1,
#   'play': 1,
#   'man': 1,
#   'trend': 1,
#   'notice': 1,
#   'xenophobic': 1,
#   'recommit': 1,
#   'fighting': 1,
#   'ruling': 1,
#   'regret': 1,
#   'lawmaker': 1,
#   'also': 1,
#   'deemed': 1,
#   'narrow': 1,
#   'boldly': 1,
#   'imperative': 1,
#   'featuring': 1,
#   'future': 1,
#   'dismantling': 1,
#   'human': 1,
#   'done': 1,
#   'born': 1,
#   'marching': 1,
#   'read': 1,
#   'march': 1,
#   'population': 1,
#   'robinson': 1,
#   'truly': 1,
#   'criminalizes': 1,
#   'murder': 1,
#   'world': 1,
#   'tool': 1,
#   'print': 1,
#   'demonstrated': 1,
#   'chance': 1,
#   'marched': 1,
#   'abdication': 1,
#   'base': 1,
#   'blackness': 1,
#   'slogan': 1,
#   'starbucks': 1,
#   'reflects': 1,
#   'accessing': 1,
#   'opposed': 1,
#   'yorkers': 1,
#   'participation': 1,
#   'beat': 1,
#   'athlete': 1,
#   'translation': 1,
#   'inmates': 1,
#   'deserve': 1,
#   'find': 1,
#   'painfully': 1,
#   'prevent': 1,
#   'nomination': 1,
#   'feel': 1,
#   'inaction': 1,
#   'campaign': 1,
#   'continue': 1,
#   'location': 1,
#   'specifically': 1,
#   'johanna': 1,
#   'hypocrite': 1,
#   'reagan': 1,
#   'eduardo': 1,
#   'coronavirus': 1,
#   'gotten': 1,
#   'lie': 1,
#   'showing': 1,
#   'surface': 1,
#   'openly': 1,
#   'jackie': 1,
#   'backgrounds': 1,
#   'accident': 1,
#   'spent': 1,
#   'societal': 1,
#   'democracy': 1,
#   'trouble': 1,
#   'refused': 1,
#   'suffering': 1,
#   'congress': 1,
#   'digestible': 1,
#   'mayor': 1,
#   'booo': 1,
#   'defend': 1,
#   'data': 1,
#   'target': 1,
#   'duke': 1,
#   'americans': 1,
#   'inspires': 1,
#   'nutshell': 1,
#   'dems': 1,
#   'richardson': 1,
#   'everybody': 1,
#   'standard': 1,
#   'collective': 1,
#   'aapi': 1,
#   'act': 1,
#   'widespread': 1,
#   'praised': 1,
#   'terrible': 1,
#   'include': 1,
#   'sainz': 1,
#   'heritage': 1,
#   'directly': 1,
#   'get': 1,
#   'disenfranchisement': 1,
#   'asked': 1,
#   'fist': 1,
#   'criminalization': 1,
#   'wide': 1,
#   'violently': 1,
#   'designed': 1,
#   'appoint': 1,
#   'pitch': 1,
#   'equitable': 1,
#   'climate': 1,
#   'understanding': 1,
#   'embrace': 1,
#   'celebrates': 1,
#   'upholding': 1,
#   'tide': 1,
#   'gap': 1,
#   'violent': 1,
#   'caused': 1,
#   'cover': 1,
#   'small': 1,
#   'body': 1,
#   'lead': 1,
#   'amplified': 1,
#   'engaging': 1,
#   'searching': 1,
#   'brought': 1,
#   'instrument': 1,
#   'us': 1,
#   'sight': 1,
#   'welcome': 1,
#   'trailblazer': 1,
#   'indictment': 1,
#   'condemn': 1,
#   'corny': 1,
#   'taking': 1,
#   'everyone': 1,
#   'hardest': 1,
#   'official': 1,
#   'shifts': 1,
#   'heart': 1,
#   'begin': 1,
#   'struggling': 1,
#   'hope': 1,
#   'defeat': 1,
#   'ca': 1,
#   'legal': 1,
#   'creating': 1,
#   'create': 1,
#   'mattered': 1,
#   'could': 1,
#   'complex': 1,
#   'futures': 1,
#   'based': 1,
#   'lastly': 1,
#   'stance': 1,
#   'taylor': 1,
#   'printer': 1,
#   'dehumanizing': 1,
#   'hitler': 1,
#   'protestor': 1,
#   'anecdote': 1,
#   'hair': 1,
#   'direction': 1,
#   'continually': 1,
#   'job': 1,
#   'security': 1,
#   'malliotakis': 1,
#   'presence': 1,
#   'modern': 1,
#   'discrimination': 1,
#   'unionize': 1,
#   'nurse': 1,
#   'speaking': 1,
#   'form': 1,
#   'taken': 1,
#   'prison': 1,
#   'traitor': 1,
#   'massive': 1,
#   'housing': 1,
#   'worked': 1,
#   'brutality': 1,
#   'crossed': 1,
#   'left': 1,
#   'jesse': 1,
#   'collection': 1,
#   'anyway': 1,
#   'spending': 1,
#   'unrest': 1,
#   'albany': 1,
#   'beyond': 1,
#   'pacific': 1,
#   'islander': 1,
#   'congratulation': 1,
#   'overtime': 1,
#   'comment': 1,
#   'rep': 1,
#   'institution': 1,
#   'close': 1,
#   'week': 1,
#   'controversial': 1,
#   'trade': 1,
#   'stripping': 1,
#   'daughter': 1,
#   'fundamental': 1,
#   'fine': 1,
#   'school': 1,
#   'raised': 1,
#   'starvation': 1,
#   'specific': 1,
#   'natural': 1,
#   'well': 1,
#   'dude': 1,
#   'shut': 1,
#   'sad': 1,
#   'wong': 1,
#   'targeted': 1,
#   'robs': 1,
#   'wealthier': 1,
#   'research': 1,
#   'express': 1,
#   'reminder': 1,
#   'mother': 1,
#   'value': 1,
#   'loveislove': 1,
#   'education': 1,
#   'story': 1,
#   'neo': 1,
#   'sync': 1,
#   'college': 1,
#   'negro': 1,
#   'interracial': 1,
#   'tackling': 1,
#   'pasted': 1,
#   'extremely': 1,
#   'atrocity': 1,
#   'county': 1,
#   'confirm': 1,
#   'quickly': 1,
#   'speaker': 1,
#   'horror': 1,
#   'use': 1,
#   'actually': 1,
#   'immigration': 1,
#   'pack': 1,
#   'consequence': 1,
#   'demanding': 1,
#   'tipping': 1,
#   'grapple': 1,
#   'dropout': 1,
#   'oppress': 1,
#   'hits': 1,
#   'kill': 1,
#   'let': 1,
#   'center': 1,
#   'ahmed': 1,
#   'chase': 1,
#   'forward': 1,
#   'used': 1,
#   'john': 1,
#   'connection': 1,
#   'industrial': 1,
#   'restaurant': 1,
#   'shooting': 1,
#   'full': 1,
#   'david': 1,
#   'largely': 1,
#   'ketanji': 1,
#   'lasting': 1,
#   'protection': 1,
#   'always': 1,
#   'still': 1,
#   'bad': 1,
#   'strategy': 1,
#   'insisted': 1,
#   'penalized': 1,
#   'ferguson': 1,
#   'powerfully': 1,
#   'book': 1,
#   'neighbors': 1,
#   'proceeds': 1,
#   'attacked': 1,
#   'moment': 1,
#   'understand': 1,
#   'committed': 1,
#   'cap': 1,
#   'including': 1,
#   'stopasianhate': 1,
#   'poverty': 1,
#   'helping': 1,
#   'wanted': 1,
#   'opposition': 1,
#   'horrified': 1,
#   'buffalo': 1,
#   'bernie': 1,
#   'nazi': 1,
#   'building': 1,
#   'lee': 1,
#   'long': 1,
#   'eradicate': 1,
#   'disproportionate': 1,
#   'meeting': 1,
#   'believe': 1,
#   'former': 1,
#   'jeff': 1,
#   'outside': 1,
#   'richmond': 1,
#   'cuéllar': 1,
#   'benefit': 1,
#   'borrower': 1,
#   'willingly': 1,
#   'demographic': 1,
#   'speak': 1,
#   'capitol': 1,
#   'appointment': 1,
#   'florida': 1,
#   'disparage': 1,
#   'kamala': 1,
#   'document': 1,
#   'harris': 1,
#   'broward': 1,
#   'redistribution': 1,
#   'united': 1,
#   'colonial': 1,
#   'larger': 1,
#   'slavery': 1,
#   'home': 1,
#   'half': 1,
#   'walk': 1,
#   'closed': 1,
#   'endorsing': 1,
#   'championship': 1,
#   'refugee': 1,
#   'bookstore': 1,
#   'choice': 1,
#   'break': 1,
#   'aspect': 1,
#   'yet': 1,
# ...
#   'zillion': 1,
#   'beginning': 1,
#   'budgeting': 1,
#   'incompetence': 1,
#   'related': 1,
#   'lost': 1,
#   'close': 1,
#   'percent': 1,
#   'shred': 1,
#   'chunk': 1,
#   'klux': 1,
#   'legitimate': 1,
#   'perilous': 1,
#   'setting': 1,
#   'driver': 1,
#   'import': 1,
#   'sanction': 1,
#   'grounding': 1,
#   'rich': 1,
#   'instinct': 1,
#   'neocolonial': 1,
#   'straightforward': 1,
#   'school': 1,
#   'hustler': 1,
#   'trafficking': 1,
#   'nationalist': 1,
#   'well': 1,
#   'huddle': 1,
#   'participatory': 1,
#   'post': 1,
#   'corruption': 1,
#   'repeated': 1,
#   'publicly': 1,
#   'prev': 1,
#   'salt': 1,
#   'ashamed': 1,
#   'knot': 1,
#   'often': 1,
#   'competent': 1,
#   'unchecked': 1,
#   'build': 1,
#   'incorrect': 1,
#   'grassroots': 1,
#   'decision': 1,
#   'reminder': 1,
#   'sizeable': 1,
#   'freelancer': 1,
#   'unsurprising': 1,
#   'little': 1,
#   'attempt': 1,
#   'pregnant': 1,
#   'education': 1,
#   'inconsistent': 1,
#   'experience': 1,
#   'nyc': 1,
#   'corp': 1,
#   'knowledge': 1,
#   'statement': 1,
#   'open': 1,
#   'cycle': 1,
#   'prioritize': 1,
#   'count': 1,
#   'seen': 1,
#   'think': 1,
#   'negotiated': 1,
#   'parl': 1,
#   'extremely': 1,
#   'mocking': 1,
#   'traditional': 1,
#   'sometimes': 1,
#   'round': 1,
#   'trick': 1,
#   'horror': 1,
#   'bills': 1,
#   'membership': 1,
#   'affect': 1,
#   'immigration': 1,
#   'autonomy': 1,
#   'consequence': 1,
#   'condition': 1,
#   'demanding': 1,
#   'revelation': 1,
#   'moderates': 1,
#   'dumping': 1,
#   'admit': 1,
#   'boyfriend': 1,
#   'joined': 1,
#   'unpopular': 1,
#   'sorry': 1,
#   'screw': 1,
#   'anywhere': 1,
#   'antisemitism': 1,
#   'dunk': 1,
#   'used': 1,
#   'collaboration': 1,
#   'stake': 1,
#   'cancun': 1,
#   'historically': 1,
#   'grps': 1,
#   'mtg': 1,
#   'restaurant': 1,
#   'brother': 1,
#   'shooting': 1,
#   'name': 1,
#   'implying': 1,
#   'unique': 1,
#   'live': 1,
#   'largely': 1,
#   'leeway': 1,
#   'always': 1,
#   'bad': 1,
#   'typo': 1,
#   'frustration': 1,
#   'negotiating': 1,
#   'action': 1,
#   'weak': 1,
#   'control': 1,
#   'moment': 1,
#   'elevates': 1,
#   'routinely': 1,
#   'going': 1,
#   'expulsion': 1,
#   'toothless': 1,
#   'widely': 1,
#   'supremacist': 1,
#   'student': 1,
#   'building': 1,
#   'long': 1,
#   'democratic': 1,
#   'impact': 1,
#   'ineptitude': 1,
#   'meantime': 1,
#   'allow': 1,
#   'divisive': 1,
#   'please': 1,
#   'fail': 1,
#   'ignored': 1,
#   'silencing': 1,
#   'theft': 1,
#   'banking': 1,
#   'rode': 1,
#   'link': 1,
#   'suggested': 1,
#   'threat': 1,
#   'enrichment': 1,
#   'heal': 1,
#   'mean': 1,
#   'shaking': 1,
#   'treat': 1,
#   'sharing': 1,
#   'volatile': 1,
#   'latest': 1,
#   'idea': 1,
#   'demand': 1,
#   'clutching': 1,
#   'describe': 1,
#   'record': 1,
#   'wages': 1,
#   'picked': 1,
#   'change': 1,
#   'perhaps': 1,
#   'intelligence': 1,
#   'alongside': 1,
#   'period': 1,
#   'evidence': 1,
#   'friendly': 1,
#   'distance': 1,
#   'meet': 1,
#   'page': 1,
#   'burning': 1,
#   'wave': 1,
#   'endorsing': 1,
#   'held': 1,
#   'alone': 1,
#   'challenging': 1,
#   'abolish': 1,
#   'favor': 1,
#   'journal': 1,
#   'huge': 1,
#   'issued': 1,
#   'jarring': 1,
#   'colleague': 1,
#   'appointing': 1,
#   'term': 1,
#   'knowingly': 1,
#   'incited': 1,
#   'inalienable': 1,
#   'blessing': 1,
#   'totally': 1,
#   'share': 1,
#   'shocked': 1,
#   'twisting': 1,
#   'threaten': 1,
#   'longer': 1,
#   'exclusion': 1,
#   'numbers': 1,
#   'playbook': 1,
#   'preventing': 1,
#   'progressive': 1,
#   'check': 1,
#   'trumpsim': 1,
#   'escalated': 1,
#   'wing': 1,
#   'gotv': 1,
#   'decisive': 1,
#   'gun': 1,
#   'approaching': 1,
#   'criticizing': 1,
#   'shoelace': 1,
#   'meetings': 1,
#   'photo': 1,
#   'helpful': 1,
#   'day': 1,
#   'pearl': 1,
#   'doe': 1,
#   'democrats': 1,
#   'funders': 1,
#   'revolve': 1,
#   'protecting': 1,
#   'built': 1,
#   'cheaper': 1,
#   'remains': 1,
#   'every': 1,
#   'behavior': 1,
#   'minor': 1,
#   'freedom': 1,
#   'feet': 1,
#   'bunch': 1,
#   'electoral': 1,
#   'harmful': 1,
#   'slam': 1,
#   'january': 1,
#   'definitely': 1,
#   'type': 1,
#   'bigotry': 1,
#   'courted': 1,
#   'million': 1,
#   'learning': 1,
#   'sending': 1,
#   'hold': 1,
#   'corporate': 1,
#   'victory': 1,
#   'sick': 1,
#   'opinion': 1,
#   'insurrectionists': 1,
#   'headline': 1,
#   'fascism': 1,
#   'implemented': 1,
#   'personally': 1,
#   'tank': 1,
#   'backed': 1,
#   'voter': 1,
#   'masquerade': 1,
#   'undermine': 1,
#   'repeal': 1,
#   'parler': 1,
#   'laid': 1,
#   'plus': 1,
#   'today': 1,
#   'ago': 1,
#   'normal': 1,
#   'pathetic': 1,
#   'ask': 1,
#   'package': 1,
#   'tired': 1,
#   'nice': 1,
#   'got': 1,
#   'boogey': 1,
#   'far': 1,
#   'complete': 1,
#   'giveaway': 1,
#   'anti': 1,
#   'handwringing': 1,
#   'alleged': 1,
#   'access': 1,
#   'believing': 1,
#   'knew': 1,
#   'ton': 1,
#   'american': 1,
#   'mind': 1,
#   'conventional': 1,
#   'mod': 1,
#   'pattern': 1,
#   'survivor': 1,
#   'targeting': 1,
#   'peep': 1,
#   'years': 1,
#   'brad': 1,
#   'aipac': 1,
#   'flying': 1,
#   'block': 1,
#   'smiling': 1,
#   'others': 1,
#   'outfitted': 1,
#   'policing': 1,
#   'moderation': 1,
#   'exaggeration': 1,
#   'codify': 1,
#   'proposed': 1,
#   'ensure': 1,
#   'abandonment': 1,
#   'said': 1,
#   'primaries': 1,
#   'mechanism': 1,
#   'financially': 1,
#   'klan': 1,
#   'planet': 1,
#   'number': 1,
#   'threshold': 1,
#   'belongs': 1,
#   'jet': 1,
#   'track': 1,
#   'place': 1,
#   'posted': 1,
#   'wake': 1,
#   'convos': 1,
#   'part': 1,
#   'holding': 1,
#   'none': 1,
#   'fire': 1,
#   'gotcha': 1,
#   'alarming': 1,
#   'agency': 1,
#   'evasion': 1,
#   'sadly': 1,
#   'saying': 1,
#   'large': 1,
#   'folk': 1,
#   'mistaken': 1,
#   'quick': 1,
#   'hall': 1,
#   'effort': 1,
#   'protests': 1,
#   'possible': 1,
#   'calling': 1,
#   'zero': 1,
#   'caps': 1,
#   'consistently': 1,
#   'prominent': 1,
#   'promised': 1,
#   'visit': 1,
#   'btw': 1,
#   'november': 1,
#   'bodily': 1,
#   'matters': 1,
#   'tumbleweed': 1,
#   'shameful': 1,
#   'took': 1,
#   'texas': 1,
#   'budget': 1,
#   'monster': 1,
#   'night': 1,
#   'muslim': 1,
#   'disagree': 1,
#   'ballot': 1,
#   'kid': 1,
#   'capitulation': 1,
#   'legislation': 1,
#   'false': 1,
#   'showtunes': 1,
#   'tactic': 1,
#   'offer': 1,
#   'either': 1,
#   'several': 1,
#   'virtue': 1,
#   'south': 1,
#   'influence': 1,
#   'losing': 1,
#   'millennials': 1,
#   'inflating': 1,
#   'platform': 1,
#   'complexity': 1,
#   'demands': 1,
#   'cake': 1,
#   'desperate': 1,
#   'frame': 1,
#   'broke': 1,
#   'cmtes': 1,
#   'assumption': 1,
#   'see': 1,
#   'squeeze': 1,
#   'attacks': 1,
#   'endorsed': 1,
#   'score': 1,
#   'unwell': 1,
#   'despite': 1,
#   'f': 1,
#   'yes': 1,
#   'non': 1,
#   'denial': 1,
#   'hard': 1,
#   'birth': 1,
#   'engaged': 1,
#   'attempting': 1,
#   'endorse': 1,
#   'ahead': 1,
#   'scandal': 1,
#   'obsession': 1,
#   'date': 1,
#   'precious': 1,
#   'delusional': 1,
#   'talking': 1,
#   'promote': 1,
#   'aside': 1},
#  ('irandeal', 19): {'irandeal': 33,
#   'president': 23,
#   'obama': 19,
#   'http': 14,
#   'iran': 12,
#   'ukraine': 9,
#   'join': 8,
#   'world': 8,
#   'country': 8,
#   'people': 8,
#   'russia': 6,
#   'question': 6,
#   'diplomacy': 5,
#   'state': 5,
#   'read': 5,
#   'make': 5,
#   'security': 5,
#   'putin': 5,
#   'american': 5,
#   'attack': 5,
#   'nuclear': 4,
#   'diplomatic': 4,
#   'agreement': 4,
#   'weapon': 4,
#   'deal': 4,
#   'policy': 4,
#   'issue': 4,
#   'secure': 4,
#   'sanction': 4,
#   'support': 4,
#   'full': 4,
#   'would': 4,
#   'international': 4,
#   'change': 4,
#   'afghanistan': 4,
#   'today': 4,
#   'conversation': 4,
#   'war': 4,
#   'foreign': 4,
#   'important': 4,
#   'america': 3,
#   'better': 3,
#   'right': 3,
#   'discus': 3,
#   'human': 3,
#   'maybe': 3,
#   'must': 3,
#   'impeachment': 3,
#   'everyone': 3,
#   'secretary': 3,
#   'information': 3,
#   'happen': 3,
#   'leading': 3,
#   'decade': 3,
#   'name': 3,
#   'going': 3,
#   'friend': 3,
#   'year': 3,
#   'many': 3,
#   'united': 3,
#   'stay': 3,
#   'check': 3,
#   'region': 3,
#   'terror': 3,
#   'place': 3,
#   'time': 3,
#   'want': 3,
#   'peace': 3,
#   'next': 3,
#   'terrorism': 3,
#   'like': 2,
#   'everywhere': 2,
#   'violates': 2,
#   'japan': 2,
#   'looking': 2,
#   'border': 2,
#   'enough': 2,
#   'also': 2,
#   'help': 2,
#   'relief': 2,
#   'clear': 2,
#   'interview': 2,
#   'program': 2,
#   'location': 2,
#   'negotiation': 2,
#   'corrupt': 2,
#   'ability': 2,
#   'among': 2,
#   'congress': 2,
#   'defend': 2,
#   'brittney': 2,
#   'council': 2,
#   'around': 2,
#   'solution': 2,
#   'potential': 2,
#   'obtaining': 2,
#   'violent': 2,
#   'month': 2,
#   'small': 2,
#   'official': 2,
#   'hope': 2,
#   'destabilization': 2,
#   'actonclimate': 2,
#   'warned': 2,
#   'keep': 2,
#   'week': 2,
#   'bahamian': 2,
#   'trump': 2,
#   'much': 2,
#   'without': 2,
#   'scientist': 2,
#   'israeli': 2,
#   'leader': 2,
#   'decision': 2,
#   'thing': 2,
#   'pm': 2,
#   'serious': 2,
#   'helped': 2,
#   'live': 2,
#   'made': 2,
#   'proliferation': 2,
#   'safer': 2,
#   'respect': 2,
#   'long': 2,
#   'former': 2,
#   'brave': 2,
#   'qaeda': 2,
#   'th': 2,
#   'fight': 2,
#   'back': 2,
#   'term': 2,
#   'argument': 2,
#   'progressive': 2,
#   'something': 2,
#   'difficult': 2,
#   'day': 2,
#   'crisis': 2,
#   'vote': 2,
#   'informed': 2,
#   'rights': 2,
#   'tell': 2,
#   'everything': 2,
#   'family': 2,
#   'historic': 2,
#   'answer': 2,
#   'fact': 2,
#   'violation': 2,
#   'national': 2,
#   'response': 2,
#   'wednesday': 2,
#   'horrific': 2,
#   'approach': 2,
#   'nation': 2,
#   'non': 2,
#   'never': 2,
#   'happened': 2,
#   'served': 1,
#   'medium': 1,
#   'participating': 1,
#   'turn': 1,
#   'measure': 1,
#   'one': 1,
#   'shuts': 1,
#   'reason': 1,
#   'sure': 1,
#   'prevents': 1,
#   'strong': 1,
#   'authoritarian': 1,
#   'whether': 1,
#   'lives': 1,
#   'established': 1,
#   'tragedy': 1,
#   'practically': 1,
#   'afghan': 1,
#   'yesterday': 1,
#   'illegally': 1,
#   'neighbor': 1,
#   'involved': 1,
#   'albright': 1,
#   'responsibility': 1,
#   'seeing': 1,
#   'public': 1,
#   'finally': 1,
#   'nail': 1,
#   'lowered': 1,
#   'might': 1,
#   'jcpoa': 1,
#   'withholding': 1,
#   'first': 1,
#   'expert': 1,
#   'custody': 1,
#   'palestinian': 1,
#   'else': 1,
#   'suffer': 1,
#   'safety': 1,
#   'implication': 1,
#   'clash': 1,
#   'immediately': 1,
#   'facilities': 1,
#   'military': 1,
#   'moving': 1,
#   'dominate': 1,
#   'east': 1,
#   'profit': 1,
#   'done': 1,
#   'finalized': 1,
#   'march': 1,
#   'strife': 1,
#   'drafted': 1,
#   'hand': 1,
#   'gratitude': 1,
#   'work': 1,
#   'manchin': 1,
#   'ndaa': 1,
#   'chastised': 1,
#   'murder': 1,
#   'malaysia': 1,
#   'alliance': 1,
#   'wondering': 1,
#   'liquidation': 1,
#   'prior': 1,
#   'initiative': 1,
#   'chance': 1,
#   'outlet': 1,
#   'bear': 1,
#   'standing': 1,
#   'overwhelming': 1,
#   'ultimately': 1,
#   'three': 1,
#   'upon': 1,
#   'courage': 1,
#   'deserve': 1,
#   'prevent': 1,
#   'structural': 1,
#   'continue': 1,
#   'pushed': 1,
#   'longtime': 1,
#   'pretending': 1,
#   'stand': 1,
#   'lie': 1,
#   'ever': 1,
#   'actual': 1,
#   'ambiguity': 1,
#   'handful': 1,
#   'unfreeze': 1,
#   'email': 1,
#   'anything': 1,
#   'bankruptcy': 1,
#   'extraordinary': 1,
#   'acknowledge': 1,
#   'refused': 1,
#   'overdue': 1,
#   'strength': 1,
#   'images': 1,
#   'effectively': 1,
#   'provides': 1,
#   'getting': 1,
#   'kennedy': 1,
#   'tooth': 1,
#   'target': 1,
#   'reconciliation': 1,
#   'midst': 1,
#   'governance': 1,
#   'voice': 1,
#   'subject': 1,
#   'powerful': 1,
#   'victim': 1,
#   'two': 1,
#   'sort': 1,
#   'terrorist': 1,
#   'york': 1,
#   'whole': 1,
#   'community': 1,
#   'heard': 1,
#   'remember': 1,
#   'asia': 1,
#   'minister': 1,
#   'ratcheted': 1,
#   'unfortunately': 1,
#   'protect': 1,
#   'objective': 1,
#   'humanity': 1,
#   'contribution': 1,
#   'thought': 1,
#   'acknowledging': 1,
#   'went': 1,
#   'driving': 1,
#   'forgotten': 1,
#   'put': 1,
#   'militarization': 1,
#   'halted': 1,
#   'us': 1,
#   'taking': 1,
#   'wisdom': 1,
#   'migration': 1,
#   'protesting': 1,
#   'heart': 1,
#   'even': 1,
#   'decency': 1,
#   'needed': 1,
#   'certain': 1,
#   'defeat': 1,
#   'ca': 1,
#   'offshore': 1,
#   'relentlessly': 1,
#   'timeline': 1,
#   'british': 1,
#   'scream': 1,
#   'across': 1,
#   'memory': 1,
#   'devoted': 1,
#   'house': 1,
#   'injured': 1,
#   'tested': 1,
#   'care': 1,
#   'achieves': 1,
#   'presence': 1,
#   'facts': 1,
#   'party': 1,
#   'spoke': 1,
#   'legitimacy': 1,
#   'taken': 1,
#   'protester': 1,
#   'street': 1,
#   'jamal': 1,
#   'cop': 1,
#   'addictive': 1,
#   'witness': 1,
#   'spending': 1,
#   'cynic': 1,
#   'compared': 1,
#   'true': 1,
#   'verbatim': 1,
#   'crackdown': 1,
#   'pacific': 1,
#   'approved': 1,
#   'breakdown': 1,
#   'attacking': 1,
#   'started': 1,
#   'saddened': 1,
#   'lost': 1,
#   'unrealistic': 1,
#   'global': 1,
#   'introduction': 1,
#   'branch': 1,
#   'unitedonclimate': 1,
#   'justify': 1,
#   'line': 1,
#   'plot': 1,
#   'general': 1,
#   'ready': 1,
#   'risked': 1,
#   'exec': 1,
#   'michelle': 1,
#   'mistake': 1,
#   'ideals': 1,
#   'third': 1,
#   'withdrawal': 1,
#   'covert': 1,
#   'requirement': 1,
#   'story': 1,
#   'oligarch': 1,
#   'article': 1,
#   'inevitable': 1,
#   'bahamas': 1,
#   'peaceful': 1,
#   'statement': 1,
#   'deploy': 1,
#   'autocrat': 1,
#   'hiroshima': 1,
#   'consider': 1,
#   'file': 1,
#   'extremely': 1,
#   'griner': 1,
#   'guest': 1,
#   'expelled': 1,
#   'follow': 1,
#   'wealth': 1,
#   'icymi': 1,
#   'afraid': 1,
#   'together': 1,
#   'consequence': 1,
#   'demanding': 1,
#   'preference': 1,
#   'myanmar': 1,
#   'billionaire': 1,
#   'let': 1,
#   'anywhere': 1,
#   'forward': 1,
#   'endless': 1,
#   'discussion': 1,
#   'surely': 1,
#   'began': 1,
#   'later': 1,
#   'sweden': 1,
#   'action': 1,
#   'adoption': 1,
#   'continuity': 1,
#   'continuously': 1,
#   'moment': 1,
#   'reality': 1,
#   'including': 1,
#   'committed': 1,
#   'provisional': 1,
#   'ed': 1,
#   'wanted': 1,
#   'glasgow': 1,
#   'surrounding': 1,
#   'progress': 1,
#   'snap': 1,
#   'believe': 1,
#   'young': 1,
#   'warning': 1,
#   'middle': 1,
#   'khashoggi': 1,
#   'news': 1,
#   'murdered': 1,
#   'readers': 1,
#   'pursuit': 1,
#   'threat': 1,
#   'tonight': 1,
#   'capitol': 1,
#   'biden': 1,
#   'administration': 1,
#   'respond': 1,
#   'consequential': 1,
#   'ukrainian': 1,
#   'spread': 1,
#   'september': 1,
#   'honor': 1,
#   'draw': 1,
#   'home': 1,
#   'walk': 1,
#   'immigrationaction': 1,
#   'resorting': 1,
#   'upended': 1,
#   'blatant': 1,
#   'courageous': 1,
#   'incentive': 1,
#   'refugee': 1,
#   'updates': 1,
#   'tough': 1,
#   'choice': 1,
#   'risk': 1,
#   'vital': 1,
#   'passing': 1,
#   'debates': 1,
#   'shocked': 1,
#   'police': 1,
#   'risking': 1,
#   'requires': 1,
#   'case': 1,
#   'told': 1,
#   'money': 1,
#   'bottom': 1,
#   'impressed': 1,
#   'power': 1,
#   'stood': 1,
#   'scenario': 1,
#   'flag': 1,
#   'making': 1,
#   'destructive': 1,
#   'myth': 1,
#   'quarantining': 1,
#   'politically': 1,
#   'loss': 1,
#   'need': 1,
#   'helpful': 1,
#   'town': 1,
#   'politician': 1,
#   'encountered': 1,
#   'resource': 1,
#   'guard': 1,
#   'government': 1,
#   'promise': 1,
#   'pressure': 1,
#   'exactly': 1,
#   'type': 1,
#   'million': 1,
#   'show': 1,
#   'initiated': 1,
#   'russian': 1,
#   'victory': 1,
#   'send': 1,
#   'effective': 1,
#   'grateful': 1,
#   'root': 1,
#   'tank': 1,
#   'life': 1,
#   'shake': 1,
#   'invasion': 1,
#   'powering': 1,
#   'nearly': 1,
#   'ago': 1,
#   'enormous': 1,
#   'apply': 1,
#   'voted': 1,
#   'op': 1,
#   'commitment': 1,
#   'cheat': 1,
#   'pathetic': 1,
#   'urging': 1,
#   'regime': 1,
#   'marine': 1,
#   'special': 1,
#   'resilience': 1,
#   'le': 1,
#   'stashed': 1,
#   'anti': 1,
#   'civilian': 1,
#   'pursued': 1,
#   'al': 1,
#   'warfare': 1,
#   'common': 1,
#   'good': 1,
#   'release': 1,
#   'aipac': 1,
#   'initial': 1,
#   'august': 1,
#   'class': 1,
#   'stamping': 1,
#   'attention': 1,
#   'paris': 1,
#   'experts': 1,
#   'pundit': 1,
#   'oligarchy': 1,
#   'ally': 1,
#   'conscience': 1,
#   'city': 1,
#   'partner': 1,
#   'breach': 1,
#   'commitments': 1,
#   'face': 1,
#   'past': 1,
#   'loved': 1,
#   'part': 1,
#   'member': 1,
#   'naïve': 1,
#   'forget': 1,
#   'expand': 1,
#   'saudi': 1,
#   'cuba': 1,
#   'incredibly': 1,
#   'colombia': 1,
#   'launch': 1,
#   'cage': 1,
#   'hall': 1,
#   'possible': 1,
#   'effort': 1,
#   'calling': 1,
#   'proof': 1,
#   'contract': 1,
#   'reached': 1,
#   'shameful': 1,
#   'fleeing': 1,
#   'bombing': 1,
#   'took': 1,
#   'vladimir': 1,
#   'already': 1,
#   'depts': 1,
#   'immoral': 1,
#   'instead': 1,
#   'extracted': 1,
#   'remain': 1,
#   'illegal': 1,
#   'team': 1,
#   'prime': 1,
#   'watch': 1,
#   'short': 1,
#   'away': 1,
#   'reaffirm': 1,
#   'rubber': 1,
#   'false': 1,
#   'offer': 1,
#   'unfolding': 1,
#   'reap': 1,
#   'several': 1,
#   'difference': 1,
#   'leave': 1,
#   'able': 1,
#   'london': 1,
#   'gave': 1,
#   'bill': 1,
#   'debunking': 1,
#   'resolution': 1,
#   'look': 1,
#   'wait': 1,
#   'suffered': 1,
#   'assumption': 1,
#   'travel': 1,
#   'pump': 1,
#   'conflict': 1,
#   'prepared': 1,
#   'supposed': 1,
#   'assassination': 1,
#   'go': 1,
#   'nothing': 1,
#   'marked': 1,
#   'energy': 1,
#   'shinzo': 1,
#   'since': 1,
#   'path': 1,
#   'resolutions': 1,
#   'kudos': 1,
#   'sale': 1}}

# %%
topic_unique_words = {}
for id, topic in topics.items():
    topic_unique_words[id] = []
    for word in topic:
        in_others = False
        for id2, topic2 in topics.items():
            if word in topic2 and id != id2:
                in_others = True
                break
        if not in_others:
            topic_unique_words[id].append(word)
# topic_unique_words
all_unique_words = []
for v in topic_unique_words.values():
    for word in v:
        all_unique_words.append(word)
all_unique_words
# Out:
# ['remarkable',
#  'beach',
#  'ring',
#  'enjoy',
#  'congressman',
#  'magdalena',
#  'meaningful',
#  'grace',
#  'anniversary',
#  'enthusiasm',
#  'fave',
#  'mentor',
#  'indigenous',
#  'entrusting',
#  'ups',
#  'dara',
#  'camping',
#  'hermanita',
#  'bumping',
#  'spirit',
#  'inspiring',
#  'notmeus',
#  'slouch',
#  'serving',
#  'generously',
#  'owen',
#  'elmhurst',
#  'graduated',
#  'brilliant',
#  'arawak',
#  'u',
#  'likewise',
#  'discounting',
#  'wood',
#  'breakthrough',
#  'westchester',
#  'recipient',
#  'cleaner',
#  'papa',
#  'bravery',
#  'impressive',
#  'evening',
#  'ancestors',
#  'sometime',
#  'artist',
#  'generosity',
#  'scottish',
#  'friendship',
#  'memories',
#  'oftentimes',
#  'nationally',
#  'jamie',
#  'rabbi',
#  'store',
#  'icon',
#  'allen',
#  'pizza',
#  'contributes',
#  'pinch',
#  'prep',
#  'pave',
#  'eastern',
#  'principal',
#  'wire',
#  'andy',
#  'reflected',
#  'rooting',
#  'shouting',
#  'cutest',
#  'orchard',
#  'presenting',
#  'trusting',
#  'enjoyed',
#  'hailey',
#  'cummings',
#  'buen',
#  'copy',
#  'fearless',
#  'provided',
#  'uplifter',
#  'bartender',
#  'dinosaur',
#  'adding',
#  'tireless',
#  'greatness',
#  'accounts',
#  'toolkits',
#  'unimaginable',
#  'valdez',
#  'shamefully',
#  'fred',
#  'p',
#  'incl',
#  'payments',
#  'hospitality',
#  'padma',
#  'arrived',
#  'generic',
#  'turning',
#  'magazine',
#  'masterful',
#  'columbine',
#  'thursday',
#  'donated',
#  'wellness',
#  'portal',
#  'unwrapped',
#  'excellence',
#  'award',
#  'taíno',
#  'tipo',
#  'pedestrian',
#  'kurt',
#  'survived',
#  'joining',
#  'advocacy',
#  'restore',
#  'lent',
#  'twins',
#  'disrespectful',
#  'gem',
#  'awesome',
#  'blown',
#  'old',
#  'puppy',
#  'misinformation',
#  'viral',
#  'retweet',
#  'tucker',
#  'covering',
#  'ignore',
#  'carlson',
#  'dosomething',
#  'traction',
#  'tripped',
#  'lmao',
#  'audience',
#  'spanish',
#  'monopolistic',
#  'beltway',
#  'photoshopped',
#  'publish',
#  'damning',
#  'uncomfortable',
#  'leadonleave',
#  'genuinely',
#  'journalism',
#  'misdeed',
#  'purge',
#  'gossip',
#  'led',
#  'respected',
#  'uprising',
#  'broadcasting',
#  'implicated',
#  'toying',
#  'verify',
#  'phony',
#  'squeezed',
#  'abused',
#  'rationing',
#  'career',
#  'james',
#  'meme',
#  'retweets',
#  'maneuvering',
#  'subscription',
#  'received',
#  'seconds',
#  'insecurity',
#  'lighter',
#  'weakens',
#  'spend',
#  'air',
#  'torrenting',
#  'dishonestly',
#  'escalate',
#  'sold',
#  'bro',
#  'whiners',
#  'brain',
#  'europe',
#  'inbox',
#  'channel',
#  'pleasure',
#  'carville',
#  'circulating',
#  'slur',
#  'accelerated',
#  'overreaction',
#  'strengthens',
#  'squash',
#  'broader',
#  'extensive',
#  'delusion',
#  'unchallenged',
#  'dragging',
#  'notch',
#  'bought',
#  'pablo',
#  'ovation',
#  'cuban',
#  'analytica',
#  'youtuber',
#  'secretly',
#  'amplification',
#  'scored',
#  'mandated',
#  'beloved',
#  'floating',
#  'intervened',
#  'crony',
#  'mails',
#  'newly',
#  'pride',
#  'qanon',
#  'newspaper',
#  'preparation',
#  'aspersion',
#  'bathroom',
#  'entitled',
#  'vilification',
#  'skews',
#  'equate',
#  'sourcing',
#  'harassed',
#  'knuckle',
#  'competition',
#  'places',
#  'institutionally',
#  'credibility',
#  'disclaimer',
#  'media',
#  'empower',
#  'leaping',
#  'tantrum',
#  'exaggerating',
#  'drama',
#  'column',
#  'gifted',
#  'cardinal',
#  'reaping',
#  'heel',
#  'bus',
#  'staple',
#  'generates',
#  'cameron',
#  'bubble',
#  'esque',
#  'books',
#  'censorship',
#  'rebrands',
#  'posting',
#  'gathering',
#  'newsroom',
#  'slapped',
#  'valued',
#  'key',
#  'internalize',
#  'equating',
#  'zuckerberg',
#  'clicks',
#  'revealing',
#  'sponsored',
#  'jacket',
#  'mission',
#  'unilaterally',
#  'kremlin',
#  'thiel',
#  'nonprofit',
#  'creep',
#  'obsessive',
#  'tossed',
#  'exhibit',
#  'critic',
#  'substantive',
#  'touching',
#  'editor',
#  'unsurprisingly',
#  'mo',
#  'distributed',
#  'evaluate',
#  'speechy',
#  'dependent',
#  'journalistic',
#  'scammy',
#  'underneath',
#  'drowned',
#  'analyst',
#  'skipping',
#  'hostile',
#  'whatsapp',
#  'insinuation',
#  'hypocritical',
#  'kessler',
#  'checked',
#  'figures',
#  'digging',
#  'diali',
#  'sellout',
#  'earnestly',
#  'dispel',
#  'lazily',
#  'fleet',
#  'explosion',
#  'cambridge',
#  'raped',
#  'nasty',
#  'noise',
#  'joe',
#  'doc',
#  'assange',
#  'classified',
#  'hunter',
#  'keystone',
#  'meekly',
#  'mishandling',
#  'nevada',
#  'bigoted',
#  'secrets',
#  'progressives',
#  'refusal',
#  'slammed',
#  'hilarious',
#  'cocaine',
#  'accord',
#  'imprecise',
#  'factory',
#  'tribute',
#  'declassify',
#  'ways',
#  'introduce',
#  'transition',
#  'buttered',
#  'abroad',
#  'offensive',
#  'felony',
#  'sleepyted',
#  'pant',
#  'feeding',
#  'posture',
#  'navy',
#  'render',
#  'mitt',
#  'asleep',
#  'insufficient',
#  'bury',
#  'pressured',
#  'indisputably',
#  'cheered',
#  'fetterman',
#  'determine',
#  'crimes',
#  'undisclosed',
#  'minutes',
#  'govern',
#  'spreading',
#  'overstated',
#  'permit',
#  'alive',
#  'defeating',
#  'observations',
#  'suppress',
#  'motif',
#  'sudden',
#  'improper',
#  'stutter',
#  'anybody',
#  'pigeons',
#  'string',
#  'archive',
#  'enact',
#  'sentence',
#  'depression',
#  'forgiving',
#  'inherit',
#  'describing',
#  'critiqued',
#  'condolence',
#  'grounds',
#  'wearing',
#  'duss',
#  'speaks',
#  'persecution',
#  'declared',
#  'divorce',
#  'maddow',
#  'temperament',
#  'foster',
#  'singal',
#  'grave',
#  'impeached',
#  'sexiest',
#  'golf',
#  'doyourjob',
#  'praising',
#  'deferentially',
#  'comeback',
#  'royal',
#  'unclear',
#  'compromised',
#  'containing',
#  'unlimited',
#  'blob',
#  'enraged',
#  'whereas',
#  'fell',
#  'lecture',
#  'handled',
#  'paths',
#  'ousted',
#  'creek',
#  'govt',
#  'tricky',
#  'vetoed',
#  'pompeo',
#  'discourse',
#  'eligibility',
#  'unable',
#  'china',
#  'romney',
#  'boldness',
#  'adopt',
#  'bench',
#  'jobs',
#  'dozen',
#  'expecting',
#  'improperly',
#  'disciplined',
#  'department',
#  'glove',
#  'begrudgingly',
#  'schoolchild',
#  'julian',
#  'headquarters',
#  'delete',
#  'format',
#  'rejoining',
#  'ceasefire',
#  'memo',
#  'garage',
#  'imprisoned',
#  'interference',
#  'wo',
#  'retracted',
#  'soccer',
#  'guardian',
#  'dealing',
#  'semi',
#  'echo',
#  'battle',
#  'trial',
#  'toomey',
#  'rebuilding',
#  'outright',
#  'western',
#  'peru',
#  'demconvention',
#  'politico',
#  'investigating',
#  'issues',
#  'bidding',
#  'bread',
#  'contrition',
#  'resembles',
#  'soil',
#  'striking',
#  'masks',
#  'spokesperson',
#  'intend',
#  'establishment',
#  'sizes',
#  'wording',
#  'underutilizing',
#  'renounced',
#  'delighted',
#  'embarrassment',
#  'recklessly',
#  'disseminated',
#  'menstruate',
#  'bible',
#  'responded',
#  'syndrome',
#  'abuela',
#  'timestamp',
#  'imposter',
#  'uterus',
#  'optional',
#  'minting',
#  'invader',
#  'inferiority',
#  'linked',
#  'referred',
#  'devastation',
#  'reposted',
#  'nap',
#  'determining',
#  'yang',
#  'addressed',
#  'liked',
#  'nowadays',
#  'alternate',
#  'qualification',
#  'ripping',
#  'fired',
#  'evoked',
#  'scene',
#  'underestimate',
#  'audio',
#  'pointed',
#  'hey',
#  'crave',
#  'functioning',
#  'disappointing',
#  'heartbreak',
#  'cc',
#  'stove',
#  'emotional',
#  'trigonometry',
#  'caution',
#  'bouquet',
#  'thumping',
#  'arrive',
#  'aggressively',
#  'compound',
#  'tear',
#  'engages',
#  'edge',
#  'menstruating',
#  'studied',
#  'sunrise',
#  'dylan',
#  'desired',
#  'chest',
#  'sauce',
#  'sotu',
#  'encounter',
#  'clickbait',
#  'confrontation',
#  'download',
#  'waiter',
#  'jack',
#  'binary',
#  'deaf',
#  'caring',
#  'newcomer',
#  'gutted',
#  'negativity',
#  'parking',
#  'inch',
#  'ripped',
#  'throttle',
#  'astounding',
#  'acted',
#  'differently',
#  'holders',
#  'snack',
#  'reminiscing',
#  'calc',
#  'distorts',
#  'handey',
#  'toddler',
#  'detractor',
#  'curved',
#  'vividly',
#  'misperception',
#  'underscore',
#  'grief',
#  'imperils',
#  'bilal',
#  'disconnect',
#  'shamble',
#  'warms',
#  'forth',
#  'picture',
#  'palin',
#  'careless',
#  'color',
#  'naacp',
#  'supremacy',
#  'tomato',
#  'mountain',
#  'satisfied',
#  'transform',
#  'holocaust',
#  'attorney',
#  'memphis',
#  'disgrace',
#  'african',
#  'assassinated',
#  'systemic',
#  'emerged',
#  'owned',
#  'teaching',
#  'diverse',
#  'sanitation',
#  'background',
#  'suspension',
#  'bluer',
#  'significantly',
#  'frisked',
#  'indicative',
#  'rant',
#  'breonna',
#  'religion',
#  'comparing',
#  'defeated',
#  'webinar',
#  'separation',
#  'rosa',
#  'trend',
#  'recommit',
#  'regret',
#  'narrow',
#  'born',
#  'marching',
#  'criminalizes',
#  'print',
#  'demonstrated',
#  'abdication',
#  'blackness',
#  'yorkers',
#  'participation',
#  'inmates',
#  'painfully',
#  'johanna',
#  'hypocrite',
#  'reagan',
#  'eduardo',
#  'backgrounds',
#  'societal',
#  'digestible',
#  'booo',
#  'duke',
#  'americans',
#  'nutshell',
#  'richardson',
#  'aapi',
#  'widespread',
#  'praised',
#  'terrible',
#  'sainz',
#  'disenfranchisement',
#  'violently',
#  'appoint',
#  'celebrates',
#  'tide',
#  'gap',
#  'caused',
#  'searching',
#  'instrument',
#  'trailblazer',
#  'indictment',
#  'corny',
#  'shifts',
#  'futures',
#  'taylor',
#  'printer',
#  'dehumanizing',
#  'hitler',
#  'protestor',
#  'continually',
#  'malliotakis',
#  'traitor',
#  'brutality',
#  'crossed',
#  'collection',
#  'unrest',
#  'albany',
#  'islander',
#  'shut',
#  'wong',
#  'robs',
#  'wealthier',
#  'negro',
#  'pasted',
#  'atrocity',
#  'county',
#  'pack',
#  'grapple',
#  'dropout',
#  'oppress',
#  'kill',
#  'ahmed',
#  'chase',
#  'industrial',
#  'lasting',
#  'penalized',
#  'ferguson',
#  'powerfully',
#  'neighbors',
#  'stopasianhate',
#  'horrified',
#  'lee',
#  'eradicate',
#  'disproportionate',
#  'jeff',
#  'richmond',
#  'cuéllar',
#  'borrower',
#  'willingly',
#  'demographic',
#  'disparage',
#  'broward',
#  'redistribution',
#  'colonial',
#  'slavery',
#  'championship',
#  'bookstore',
#  'wnba',
#  'player',
#  'liar',
#  'hung',
#  'n',
#  'swim',
#  'trotting',
#  'civic',
#  'fragile',
#  'skin',
#  'prejudice',
#  'stell',
#  'reconsider',
#  'congratulate',
#  'fever',
#  'clue',
#  'toothpick',
#  'moumita',
#  'soundbite',
#  'solved',
#  'knowing',
#  'india',
#  'strikeforblacklives',
#  'forcefully',
#  'grads',
#  'ban',
#  'sanitize',
#  'locking',
#  'moved',
#  'excuse',
#  'stoked',
#  'comfortable',
#  'garbage',
#  'devastates',
#  'rev',
#  'slave',
#  'trayvon',
#  'hating',
#  'essay',
#  'rising',
#  'backtrack',
#  'giant',
#  'pathological',
#  'misogyny',
#  'blacklivesmatter',
#  'oppression',
#  'vile',
#  'troubling',
#  'scepter',
#  'sentenced',
#  'republicanism',
#  'da',
#  'slum',
#  'hateful',
#  'advocating',
#  'absence',
#  'josé',
#  'club',
#  'confederate',
#  'launched',
#  'hypocrisy',
#  'turnout',
#  'endorsement',
#  'poll',
#  'strengthen',
#  'badge',
#  'ranking',
#  'disposal',
#  'forum',
#  'underperformance',
#  'thrive',
#  'phonebanking',
#  'entirely',
#  'hours',
#  'developments',
#  'extra',
#  'mess',
#  'easily',
#  'warnock',
#  'cooper',
#  'sleep',
#  'occurs',
#  'assembled',
#  'disastrous',
#  'heroic',
#  'gerrymandering',
#  'protocols',
#  'iron',
#  'systematically',
#  'prolific',
#  'discouraged',
#  'indicated',
#  'personality',
#  'dakota',
#  'insight',
#  'challenges',
#  'weekends',
#  'avenue',
#  'qualify',
#  'thankfully',
#  'min',
#  'suspend',
#  'things',
#  'sh',
#  'georgian',
#  'wiggle',
#  'concession',
#  'chaplain',
#  'dreamer',
#  'fundraisers',
#  'apoplectic',
#  'virtually',
#  'firmly',
#  'reverend',
#  'represents',
#  'quiet',
#  'accusing',
#  'certification',
#  'gooo',
#  'potentially',
#  'offices',
#  'ballots',
#  'reintroduced',
#  'calls',
#  'folding',
#  'secured',
#  'demoralizing',
#  'racing',
#  'halting',
#  'ranked',
#  'viewable',
#  'disenfranchised',
#  'historical',
#  'belong',
#  'crawling',
#  'conmijente',
#  'phonebank',
#  'lewis',
#  'hashtag',
#  'disingenuously',
#  'supporters',
#  'works',
#  'cruel',
#  'translates',
#  'affordable',
#  'asmr',
#  'usually',
#  'resolve',
#  'recommend',
#  'sieging',
#  'relentless',
#  'standalone',
#  'disappointment',
#  'resurrect',
#  'noted',
#  'determinant',
#  'mos',
#  'races',
#  'exist',
#  'christopherhall',
#  'rarely',
#  'calcified',
#  'sorts',
#  'michigan',
#  'juegan',
#  'normally',
#  'cd',
#  'motivate',
#  'medicaid',
#  'principle',
#  'electors',
#  'midnight',
#  'bc',
#  'rediscover',
#  'sighted',
#  'polls',
#  'cands',
#  'prioritizing',
#  'browbeating',
#  'referendum',
#  'poetic',
#  'ideological',
#  'claimed',
#  'collapse',
#  'courting',
#  'drive',
#  'democracyforum',
#  'unravel',
#  'vacation',
#  'fundraising',
#  'sample',
#  'understated',
#  'december',
#  'edition',
#  'easter',
#  'thirteen',
#  'sixty',
#  'eleven',
#  'bloody',
#  'six',
#  'mandela',
#  'waitressed',
#  'hispanic',
#  'eighty',
#  'garden',
#  'tuesday',
#  'fifty',
#  'holiday',
#  'kola',
#  'solidaridad',
#  'lech',
#  'iii',
#  'descendant',
#  'seis',
#  'offense',
#  'champagne',
#  'cerave',
#  'serum',
#  'bronze',
#  'elia',
#  'noodle',
#  'aquí',
#  'clotilda',
#  'battlestar',
#  'fuera',
#  'familias',
#  'taxtherich',
#  'drunken',
#  'concentration',
#  'luma',
#  'daunte',
#  'pocas',
#  'centro',
#  'birdcage',
#  'capicús',
#  'powder',
#  'dash',
#  'mucho',
#  'rivera',
#  'stash',
#  'está',
#  'feature',
#  'cubanos',
#  'trajeron',
#  'warren',
#  'garcia',
#  'cloakroom',
#  'patriarcado',
#  'skirt',
#  'bottle',
#  'puertoriconosevende',
#  'beets',
#  'preserved',
#  'estamos',
#  'wooden',
#  'chaiquito',
#  'belafonte',
#  'ves',
#  'galactica',
#  'lucha',
#  'bears',
#  'rihanna',
#  'soscolombia',
#  'movie',
#  'cantando',
#  'sylvia',
#  'violencia',
#  'orange',
#  'nueces',
#  'shana',
#  'ummmm',
#  'todes',
#  'asientos',
#  'bull',
#  'siri',
#  'mayamentum',
#  'ride',
#  'sandwich',
#  'historian',
#  'mystery',
#  'vota',
#  'olaf',
#  'watermelon',
#  'dunce',
#  'reyes',
#  'harry',
#  'jan',
#  'cars',
#  'powdered',
#  'compilation',
#  'drugstore',
#  ...]

# %%
topic_word_probs = {}
goodness_score = {}
topic_score = {}
for id, topic in topics.items():
    topic_score[id] = {}
    topic_count = 0
    for word, count in topic.items():
        topic_count += count
        # if word in all_unique_words:
        #     continue
        tot_count = count
        for id2, topic2 in topics.items():
            if word in topic2 and id != id2:
                tot_count += topic2[word]
        if word not in topic_word_probs:
            topic_word_probs[word] = {}
            goodness_score[word] = {}
        topic_word_probs[word][id] = count / tot_count
        goodness_score[word][id] = count / tot_count * count
        topic_score[id][word] = count / tot_count * count
    # topic_score[id] = {word: count / topic_count for word, count in topic_score[id].items()}
goodness_score
topic_score = {id: {word: score for word, score in sorted(topic.items(), key = lambda x: -x[1])[:5]} for id,  topic in topic_score.items()}
topic_score
# Out:
# {('thank', 0): {'thank': 14.89655172413793,
#   'happy': 9.96551724137931,
#   'proud': 7.3478260869565215,
#   'wonderful': 5.142857142857142,
#   'congratulation': 2.5},
#  ('truth', 1): {'truth': 15.428571428571427,
#   'misinformation': 9.0,
#   'team': 8.533333333333333,
#   'facebook': 4.5,
#   'tweet': 3.5},
#  ('biden', 2): {'biden': 99.84033613445378,
#   'president': 5.813186813186813,
#   'joe': 5.0,
#   'admin': 4.266666666666667,
#   'doc': 4.0},
#  ('people', 3): {'menstruate': 3.0,
#   'bible': 2.0,
#   'responded': 2.0,
#   'syndrome': 2.0,
#   'abuela': 2.0},
#  ('black', 4): {'black': 26.133333333333333,
#   'racist': 14.222222222222221,
#   'color': 13.0,
#   'racial': 10.5625,
#   'white': 10.314285714285713},
#  ('vote', 5): {'vote': 29.866666666666667,
#   'ballot': 10.5625,
#   'election': 6.4799999999999995,
#   'polling': 6.125,
#   'voter': 5.818181818181818},
#  ('year', 6): {'year': 10.010416666666668,
#   'today': 6.127450980392156,
#   'ago': 5.263157894736842,
#   'last': 3.5,
#   'yesterday': 2.8823529411764706},
#  ('one', 7): {'kola': 3.0,
#   'solidaridad': 2.0,
#   'lech': 2.0,
#   'iii': 2.0,
#   'descendant': 2.0},
#  ('people', 8): {'extremist': 4.0,
#   'seize': 4.0,
#   'people': 3.7834645669291342,
#   'abuse': 3.5999999999999996,
#   'anti': 3.5555555555555554},
#  ('president', 9): {'center': 12.25,
#   'presidential': 9.38888888888889,
#   'chicago': 5.444444444444445,
#   'obama': 5.113636363636363,
#   'presidency': 5.0},
#  ('congress', 10): {'senate': 17.06451612903226,
#   'court': 13.761904761904763,
#   'filibuster': 6.666666666666666,
#   'bill': 5.921052631578948,
#   'congress': 5.813186813186813},
#  ('people', 11): {'stock': 6.75,
#   'corporate': 5.555555555555555,
#   'trillion': 5.0,
#   'money': 4.172413793103448,
#   'billionaire': 3.0625},
#  ('time', 12): {'sign': 3.0,
#   'monthly': 3.0,
#   'minute': 2.6666666666666665,
#   'town': 2.5,
#   'hall': 2.5},
#  ('thank', 13): {'thank': 2.586206896551724,
#   'alright': 2.0,
#   'alternatively': 2.0,
#   'fast': 1.3333333333333333,
#   'anyways': 1.0},
#  ('covid', 14): {'covid': 36.93846153846154,
#   'vaccine': 31.0,
#   'pandemic': 22.400000000000002,
#   'vaccinated': 11.0,
#   'health': 7.111111111111111},
#  ('people', 15): {'childcare': 6.0,
#   'healthcare': 4.923076923076923,
#   'loan': 4.454545454545454,
#   'fema': 4.0,
#   'help': 3.9054054054054057},
#  ('people', 16): {'police': 11.115384615384615,
#   'capitol': 5.297297297297297,
#   'assault': 4.571428571428571,
#   'surveillance': 4.166666666666667,
#   'incident': 4.0},
#  ('climate', 17): {'climate': 61.25,
#   'change': 17.852459016393443,
#   'planet': 9.307692307692308,
#   'emission': 7.0,
#   'hydrogen': 7.0},
#  ('republican', 18): {'republican': 27.38,
#   'dems': 9.633333333333333,
#   'bipartisan': 7.6818181818181825,
#   'mccarthy': 7.363636363636364,
#   'party': 5.357142857142858},
#  ('irandeal', 19): {'irandeal': 33.0,
#   'iran': 10.285714285714285,
#   'http': 8.909090909090908,
#   'obama': 8.204545454545455,
#   'ukraine': 8.1}}

# %%
unique_topic_score_words = {}
for id, topic in topic_score.items():
    unique_topic_score_words[id] = {}
    for word in topic:
        is_unique = True
        for id2, topic2 in topic_score.items():
            if id != id2 and word in topic2: 
                is_unique = False
                break
        if is_unique:
            unique_topic_score_words[id][word] = topic[word]
unique_topic_score_words
# Out:
# {('thank', 0): {'happy': 9.96551724137931,
#   'proud': 7.3478260869565215,
#   'wonderful': 5.142857142857142,
#   'congratulation': 2.5},
#  ('truth', 1): {'truth': 15.428571428571427,
#   'misinformation': 9.0,
#   'team': 8.533333333333333,
#   'facebook': 4.5,
#   'tweet': 3.5},
#  ('biden', 2): {'biden': 99.84033613445378,
#   'president': 5.813186813186813,
#   'joe': 5.0,
#   'admin': 4.266666666666667,
#   'doc': 4.0},
#  ('people', 3): {'menstruate': 3.0,
#   'bible': 2.0,
#   'responded': 2.0,
#   'syndrome': 2.0,
#   'abuela': 2.0},
#  ('black', 4): {'black': 26.133333333333333,
#   'racist': 14.222222222222221,
#   'color': 13.0,
#   'racial': 10.5625,
#   'white': 10.314285714285713},
#  ('vote', 5): {'vote': 29.866666666666667,
#   'ballot': 10.5625,
#   'election': 6.4799999999999995,
#   'polling': 6.125,
#   'voter': 5.818181818181818},
#  ('year', 6): {'year': 10.010416666666668,
#   'today': 6.127450980392156,
#   'ago': 5.263157894736842,
#   'last': 3.5,
#   'yesterday': 2.8823529411764706},
#  ('one', 7): {'kola': 3.0,
#   'solidaridad': 2.0,
#   'lech': 2.0,
#   'iii': 2.0,
#   'descendant': 2.0},
#  ('people', 8): {'extremist': 4.0,
#   'seize': 4.0,
#   'people': 3.7834645669291342,
#   'abuse': 3.5999999999999996,
#   'anti': 3.5555555555555554},
#  ('president', 9): {'center': 12.25,
#   'presidential': 9.38888888888889,
#   'chicago': 5.444444444444445,
#   'presidency': 5.0},
#  ('congress', 10): {'senate': 17.06451612903226,
#   'court': 13.761904761904763,
#   'filibuster': 6.666666666666666,
#   'bill': 5.921052631578948,
#   'congress': 5.813186813186813},
#  ('people', 11): {'stock': 6.75,
#   'corporate': 5.555555555555555,
#   'trillion': 5.0,
#   'money': 4.172413793103448,
#   'billionaire': 3.0625},
#  ('time', 12): {'sign': 3.0,
#   'monthly': 3.0,
#   'minute': 2.6666666666666665,
#   'town': 2.5,
#   'hall': 2.5},
#  ('thank', 13): {'alright': 2.0,
#   'alternatively': 2.0,
#   'fast': 1.3333333333333333,
#   'anyways': 1.0},
#  ('covid', 14): {'covid': 36.93846153846154,
#   'vaccine': 31.0,
#   'pandemic': 22.400000000000002,
#   'vaccinated': 11.0,
#   'health': 7.111111111111111},
#  ('people', 15): {'childcare': 6.0,
#   'healthcare': 4.923076923076923,
#   'loan': 4.454545454545454,
#   'fema': 4.0,
#   'help': 3.9054054054054057},
#  ('people', 16): {'police': 11.115384615384615,
#   'capitol': 5.297297297297297,
#   'assault': 4.571428571428571,
#   'surveillance': 4.166666666666667,
#   'incident': 4.0},
#  ('climate', 17): {'climate': 61.25,
#   'change': 17.852459016393443,
#   'planet': 9.307692307692308,
#   'emission': 7.0,
#   'hydrogen': 7.0},
#  ('republican', 18): {'republican': 27.38,
#   'dems': 9.633333333333333,
#   'bipartisan': 7.6818181818181825,
#   'mccarthy': 7.363636363636364,
#   'party': 5.357142857142858},
#  ('irandeal', 19): {'irandeal': 33.0,
#   'iran': 10.285714285714285,
#   'http': 8.909090909090908,
#   'ukraine': 8.1}}

# %%
from itertools import permutations

queries = {}
for id, topic in unique_topic_score_words.items():
    queries[id] = '(' + ') OR ('.join(' '.join(x) for x in permutations(topic.keys(), 2)) + ')'
queries
# Out:
# {('thank',
#   0): '(happy proud) OR (happy wonderful) OR (happy congratulation) OR (proud happy) OR (proud wonderful) OR (proud congratulation) OR (wonderful happy) OR (wonderful proud) OR (wonderful congratulation) OR (congratulation happy) OR (congratulation proud) OR (congratulation wonderful)',
#  ('truth',
#   1): '(truth misinformation) OR (truth team) OR (truth facebook) OR (truth tweet) OR (misinformation truth) OR (misinformation team) OR (misinformation facebook) OR (misinformation tweet) OR (team truth) OR (team misinformation) OR (team facebook) OR (team tweet) OR (facebook truth) OR (facebook misinformation) OR (facebook team) OR (facebook tweet) OR (tweet truth) OR (tweet misinformation) OR (tweet team) OR (tweet facebook)',
#  ('biden',
#   2): '(biden president) OR (biden joe) OR (biden admin) OR (biden doc) OR (president biden) OR (president joe) OR (president admin) OR (president doc) OR (joe biden) OR (joe president) OR (joe admin) OR (joe doc) OR (admin biden) OR (admin president) OR (admin joe) OR (admin doc) OR (doc biden) OR (doc president) OR (doc joe) OR (doc admin)',
#  ('people',
#   3): '(menstruate bible) OR (menstruate responded) OR (menstruate syndrome) OR (menstruate abuela) OR (bible menstruate) OR (bible responded) OR (bible syndrome) OR (bible abuela) OR (responded menstruate) OR (responded bible) OR (responded syndrome) OR (responded abuela) OR (syndrome menstruate) OR (syndrome bible) OR (syndrome responded) OR (syndrome abuela) OR (abuela menstruate) OR (abuela bible) OR (abuela responded) OR (abuela syndrome)',
#  ('black',
#   4): '(black racist) OR (black color) OR (black racial) OR (black white) OR (racist black) OR (racist color) OR (racist racial) OR (racist white) OR (color black) OR (color racist) OR (color racial) OR (color white) OR (racial black) OR (racial racist) OR (racial color) OR (racial white) OR (white black) OR (white racist) OR (white color) OR (white racial)',
#  ('vote',
#   5): '(vote ballot) OR (vote election) OR (vote polling) OR (vote voter) OR (ballot vote) OR (ballot election) OR (ballot polling) OR (ballot voter) OR (election vote) OR (election ballot) OR (election polling) OR (election voter) OR (polling vote) OR (polling ballot) OR (polling election) OR (polling voter) OR (voter vote) OR (voter ballot) OR (voter election) OR (voter polling)',
#  ('year',
#   6): '(year today) OR (year ago) OR (year last) OR (year yesterday) OR (today year) OR (today ago) OR (today last) OR (today yesterday) OR (ago year) OR (ago today) OR (ago last) OR (ago yesterday) OR (last year) OR (last today) OR (last ago) OR (last yesterday) OR (yesterday year) OR (yesterday today) OR (yesterday ago) OR (yesterday last)',
#  ('one',
#   7): '(kola solidaridad) OR (kola lech) OR (kola iii) OR (kola descendant) OR (solidaridad kola) OR (solidaridad lech) OR (solidaridad iii) OR (solidaridad descendant) OR (lech kola) OR (lech solidaridad) OR (lech iii) OR (lech descendant) OR (iii kola) OR (iii solidaridad) OR (iii lech) OR (iii descendant) OR (descendant kola) OR (descendant solidaridad) OR (descendant lech) OR (descendant iii)',
#  ('people',
#   8): '(extremist seize) OR (extremist people) OR (extremist abuse) OR (extremist anti) OR (seize extremist) OR (seize people) OR (seize abuse) OR (seize anti) OR (people extremist) OR (people seize) OR (people abuse) OR (people anti) OR (abuse extremist) OR (abuse seize) OR (abuse people) OR (abuse anti) OR (anti extremist) OR (anti seize) OR (anti people) OR (anti abuse)',
#  ('president',
#   9): '(center presidential) OR (center chicago) OR (center presidency) OR (presidential center) OR (presidential chicago) OR (presidential presidency) OR (chicago center) OR (chicago presidential) OR (chicago presidency) OR (presidency center) OR (presidency presidential) OR (presidency chicago)',
#  ('congress',
#   10): '(senate court) OR (senate filibuster) OR (senate bill) OR (senate congress) OR (court senate) OR (court filibuster) OR (court bill) OR (court congress) OR (filibuster senate) OR (filibuster court) OR (filibuster bill) OR (filibuster congress) OR (bill senate) OR (bill court) OR (bill filibuster) OR (bill congress) OR (congress senate) OR (congress court) OR (congress filibuster) OR (congress bill)',
#  ('people',
#   11): '(stock corporate) OR (stock trillion) OR (stock money) OR (stock billionaire) OR (corporate stock) OR (corporate trillion) OR (corporate money) OR (corporate billionaire) OR (trillion stock) OR (trillion corporate) OR (trillion money) OR (trillion billionaire) OR (money stock) OR (money corporate) OR (money trillion) OR (money billionaire) OR (billionaire stock) OR (billionaire corporate) OR (billionaire trillion) OR (billionaire money)',
#  ('time',
#   12): '(sign monthly) OR (sign minute) OR (sign town) OR (sign hall) OR (monthly sign) OR (monthly minute) OR (monthly town) OR (monthly hall) OR (minute sign) OR (minute monthly) OR (minute town) OR (minute hall) OR (town sign) OR (town monthly) OR (town minute) OR (town hall) OR (hall sign) OR (hall monthly) OR (hall minute) OR (hall town)',
#  ('thank',
#   13): '(alright alternatively) OR (alright fast) OR (alright anyways) OR (alternatively alright) OR (alternatively fast) OR (alternatively anyways) OR (fast alright) OR (fast alternatively) OR (fast anyways) OR (anyways alright) OR (anyways alternatively) OR (anyways fast)',
#  ('covid',
#   14): '(covid vaccine) OR (covid pandemic) OR (covid vaccinated) OR (covid health) OR (vaccine covid) OR (vaccine pandemic) OR (vaccine vaccinated) OR (vaccine health) OR (pandemic covid) OR (pandemic vaccine) OR (pandemic vaccinated) OR (pandemic health) OR (vaccinated covid) OR (vaccinated vaccine) OR (vaccinated pandemic) OR (vaccinated health) OR (health covid) OR (health vaccine) OR (health pandemic) OR (health vaccinated)',
#  ('people',
#   15): '(childcare healthcare) OR (childcare loan) OR (childcare fema) OR (childcare help) OR (healthcare childcare) OR (healthcare loan) OR (healthcare fema) OR (healthcare help) OR (loan childcare) OR (loan healthcare) OR (loan fema) OR (loan help) OR (fema childcare) OR (fema healthcare) OR (fema loan) OR (fema help) OR (help childcare) OR (help healthcare) OR (help loan) OR (help fema)',
#  ('people',
#   16): '(police capitol) OR (police assault) OR (police surveillance) OR (police incident) OR (capitol police) OR (capitol assault) OR (capitol surveillance) OR (capitol incident) OR (assault police) OR (assault capitol) OR (assault surveillance) OR (assault incident) OR (surveillance police) OR (surveillance capitol) OR (surveillance assault) OR (surveillance incident) OR (incident police) OR (incident capitol) OR (incident assault) OR (incident surveillance)',
#  ('climate',
#   17): '(climate change) OR (climate planet) OR (climate emission) OR (climate hydrogen) OR (change climate) OR (change planet) OR (change emission) OR (change hydrogen) OR (planet climate) OR (planet change) OR (planet emission) OR (planet hydrogen) OR (emission climate) OR (emission change) OR (emission planet) OR (emission hydrogen) OR (hydrogen climate) OR (hydrogen change) OR (hydrogen planet) OR (hydrogen emission)',
#  ('republican',
#   18): '(republican dems) OR (republican bipartisan) OR (republican mccarthy) OR (republican party) OR (dems republican) OR (dems bipartisan) OR (dems mccarthy) OR (dems party) OR (bipartisan republican) OR (bipartisan dems) OR (bipartisan mccarthy) OR (bipartisan party) OR (mccarthy republican) OR (mccarthy dems) OR (mccarthy bipartisan) OR (mccarthy party) OR (party republican) OR (party dems) OR (party bipartisan) OR (party mccarthy)',
#  ('irandeal',
#   19): '(irandeal iran) OR (irandeal http) OR (irandeal ukraine) OR (iran irandeal) OR (iran http) OR (iran ukraine) OR (http irandeal) OR (http iran) OR (http ukraine) OR (ukraine irandeal) OR (ukraine iran) OR (ukraine http)'}

# %%
import requests

auth_req = requests.post(url='https://api.twitter.com/oauth2/token', params={'grant_type': 'client_credentials'}, auth=('VCfwIgAUXitR1LUG738fmWOw0','zlUPoVTRnruUvrUzcixBttY28K84PepKtZCtnaxTz6hSPzhkAX'))

print(auth_req.json())

tok = auth_req.json()['access_token']

print(f"Bearer {tok}")
# Out:
# {'token_type': 'bearer', 'access_token': 'AAAAAAAAAAAAAAAAAAAAANHDlgEAAAAAOKeeIlP4HjjWnSyfuKrFCB2uY8E%3D9RWP4AjkdXlvWkxbFuS4HgazJY5Xup1finTMvQrCbIe28ODh4c'}
# Bearer AAAAAAAAAAAAAAAAAAAAANHDlgEAAAAAOKeeIlP4HjjWnSyfuKrFCB2uY8E%3D9RWP4AjkdXlvWkxbFuS4HgazJY5Xup1finTMvQrCbIe28ODh4c

# %%
from random import choice

topic_no = choice(list(queries.keys()))

climate_query = f"({queries[topic_no]})"
climate_query += ' -is:retweet -is:quote'
# climate_query = '(climate AND change) OR (climate AND planet)'
print(climate_query)


req = requests.get(url='https://api.twitter.com/2/tweets/search/recent', headers={'Authorization': f"Bearer {tok}"},params={'query': climate_query, 'tweet.fields': 'text', 'max_results': '100'})

match_tweets = req.json()

match_tweets_text = [tweet['text'] for tweet in match_tweets['data']]

match_tweets
# Out:
# ((happy proud) OR (happy wonderful) OR (happy congratulation) OR (proud happy) OR (proud wonderful) OR (proud congratulation) OR (wonderful happy) OR (wonderful proud) OR (wonderful congratulation) OR (congratulation happy) OR (congratulation proud) OR (congratulation wonderful)) -is:retweet -is:quote
# {'data': [{'edit_history_tweet_ids': ['1635515948273750016'],
#    'id': '1635515948273750016',
#    'text': "Happy birthday to my beautiful Tia! It's an honor to have the same birthday month with this amazing, wonderful woman! Love you so much! May God bless you always! ❤️🥰🎂🎉 https://t.co/3M6GNvU7VT"},
#   {'edit_history_tweet_ids': ['1635515913796739073'],
#    'id': '1635515913796739073',
#    'text': '@BeardedGregU happy birthday friend!\n\ni love you im proud of you and im always gonna be cheering you on homie!\n\nHeres to Self love progression and success!'},
#   {'edit_history_tweet_ids': ['1635515886093340674'],
#    'id': '1635515886093340674',
#    'text': '@helena_mar19 Good Morning dear helen 🌺🌺🌺\nI wish you a wonderful and happy \nTuesday. Take care my friend...and \nEnjoy your day ⚘🍎☕🍒🍩🌞🌻🥀 https://t.co/ZgX7xukYui'},
#   {'edit_history_tweet_ids': ['1635515787254566913'],
#    'id': '1635515787254566913',
#    'text': "Team #HamsiniEntertainment Wishing a happy birthday to @Dir_Lokesh 🎂 \n\nThank you for the Hat-trick Blockbusters #Kaithi #Master &amp; #Vikram 🔥 We're proud that we have delivered these movies across the world ❤️ \n\nNext #Leo Sambavam loading 💥💥 \n\n#HappyBirthdayLokesh… https://t.co/oUgUo1x7MI https://t.co/gaveCZaDYN"},
#   {'edit_history_tweet_ids': ['1635515739921694721'],
#    'id': '1635515739921694721',
#    'text': "@fagalex67 Thanks so much bro  and congratulation on your big win , bro i need laptop for my engineering work , i will be happy to send this 41k winning for any small laptop , if u can pls help out , i really need it,  i don't have much to buy expensive one thanks https://t.co/DnrUab76rN"},
#   {'edit_history_tweet_ids': ['1635515632660762624'],
#    'id': '1635515632660762624',
#    'text': 'You know, if I die today, I can at least die happy knowing Zentreya saw my gamertag, loved it, and recognized me. That was so wonderful haha https://t.co/pnSnVSodF2'},
#   {'edit_history_tweet_ids': ['1635515617502429185'],
#    'id': '1635515617502429185',
#    'text': "Morning Cityzens, am proud coz it's matchday in #ucl against RB Leipzig, hope everybody is happy. #ManCity https://t.co/itiBKpTDTw"},
#   {'edit_history_tweet_ids': ['1635515508006215682'],
#    'id': '1635515508006215682',
#    'text': '@tbhAnubhav Happy &amp; proud for u ☺️❤️🫂 More power to u &amp; to the entire team too. 🫂 Keep going, keep shining &amp; keep inspiring forever.❤️✨👍🏻 Regards, Best wishes &amp; lots of good energy. 🙏🏻❤️🫂'},
#   {'edit_history_tweet_ids': ['1635515009873907713'],
#    'id': '1635515009873907713',
#    'text': 'AA2787dear, wish you a wonderful and happy life   #长沙   https://t.co/2FtTzBstsi'},
#   {'edit_history_tweet_ids': ['1635515003846676480'],
#    'id': '1635515003846676480',
#    'text': '@ChandrimaRaksh2 @Gashmeer Thank you so much dear! I’m so happy I got a reply for the first time! 🤗 Yes for sure proud of our dear  Hero &amp; wish him all the success! 🤗💖 #GashmeerMahajani #TereIshqMeinGhayal'},
#   {'edit_history_tweet_ids': ['1635515001086640130'],
#    'id': '1635515001086640130',
#    'text': '@Pontifex Happy 10th anniversary since your election as Pontiff. Thanks for all the wonderful changes and clarifications you have brought to The Church, you warmth, your wit, and your love. God bless you!'},
#   {'edit_history_tweet_ids': ['1635514945398865920'],
#    'id': '1635514945398865920',
#    'text': 'Happy happy birthday Amay! ❤️.\n Have a wonderful year ahead nd wishing u all the happiness and success..💫 Love u to the jupiter nd back⚘️! \n      \nStay the same always\U0001f979\n\n@amaya_krishnan • \n#Happybirthdaycutekutty 😔👌 https://t.co/frvpQe4aYs'},
#   {'edit_history_tweet_ids': ['1635514930907553793'],
#    'id': '1635514930907553793',
#    'text': '@angelica007006 Happy chewsday, Angelica.\nHope you have a wonderful day.\nKeep safe and warm.\nLove RupeeXXX ♥️💗💓'},
#   {'edit_history_tweet_ids': ['1635514833356611585'],
#    'id': '1635514833356611585',
#    'text': '@sayvooplay \nHappy Birthday Ronald🌹\n\nI hope you have another wonderful year.☺️🙏 https://t.co/iBPdG3S2VR'},
#   {'edit_history_tweet_ids': ['1635514727882272768'],
#    'id': '1635514727882272768',
#    'text': '@OgunsipePhilip Happy birthday Philz \nHave a wonderful new year bro \nAgba chef 🙌🙌'},
#   {'edit_history_tweet_ids': ['1635514700065636353'],
#    'id': '1635514700065636353',
#    'text': '@MIRROR_lMAGE you do ? \n\n     [ * a pleasantly surprised twitch of his nose , before a rumbly , happy noise akin to a purr rises in his voice as he speaks . ] \n\nyes . not everything , but almost everything humans know . \n\n[ * puffing his chest out . he ’ s very proud . ] https://t.co/JvuFrXpj6o'},
#   {'edit_history_tweet_ids': ['1635514599792427009'],
#    'id': '1635514599792427009',
#    'text': '@MakaratiFrank Happy birthday muravi, keep going bro we are so proud of you'},
#   {'edit_history_tweet_ids': ['1635514556884631555'],
#    'id': '1635514556884631555',
#    'text': "for anyone who needs to hear it, (A small thread)\nYou're doing wonderful and I'm proud of you. You're important and you matter if you don't have the motivation and energy to get out of bed that's fine be productive when you're ready to,"},
#   {'edit_history_tweet_ids': ['1635514552388288512'],
#    'id': '1635514552388288512',
#    'text': "Happy 18th Founders Day! We're proud to carry on the legacy of our company and deliver exceptional service to our valuable customers.  We are grateful to have you as a part of our growing community and appreciate your contribution to our success - Solitaire Valley \n\n#foundersday https://t.co/Uyj459TI1u"},
#   {'edit_history_tweet_ids': ['1635514546172608513'],
#    'id': '1635514546172608513',
#    'text': '"Are you going to wash your man cloth?"😅\n\n(Look how proud and happy she was)\n\n#mimiguli #randomship https://t.co/hYUUnil1XW'},
#   {'edit_history_tweet_ids': ['1635514464186544130'],
#    'id': '1635514464186544130',
#    'text': '@eva_lequeen GAGI MAMI /SRS BA ANG EVAKOY HSKSJA SO PROUD AND HAPPY FOR YOU MAMA!!!!!!!!!'},
#   {'edit_history_tweet_ids': ['1635514434276974592'],
#    'id': '1635514434276974592',
#    'text': '@VoilaAmbreen \nGood Morning Ambreen 🌺🌺🌺\nI wish you a wonderful and happy \nTuesday. Take care my friend...and \nEnjoy your day ⚘🍎☕🍒🍩🌞🌻🥀 https://t.co/Fzm3VEmsPy'},
#   {'edit_history_tweet_ids': ['1635514312709271553'],
#    'id': '1635514312709271553',
#    'text': 'Hbd selamat happy birthday airaaa,hopefully all your dreams come true and you can make your parents proud, today and so on you are as bright as the sun,ily++🥳🤩 @swtxadorable https://t.co/tL8FemSoV0'},
#   {'edit_history_tweet_ids': ['1635514301355270145'],
#    'id': '1635514301355270145',
#    'text': '@warriors Happy Birthday Steph, making Bay proud since you stepped into their ground years back.\nMay The God Lord Who has you for Himself and awarded you with NBA gifts continue to add many healthy years to your life &amp; family IJN,Amen.'},
#   {'edit_history_tweet_ids': ['1635514281432170496'],
#    'id': '1635514281432170496',
#    'text': '@tallgirlalli Happy birthday sweet girl!  May this new year be full of blessings and wonderful things. Lots of love and prosperity. You are beautifully made. 🥰'},
#   {'edit_history_tweet_ids': ['1635514275966877696'],
#    'id': '1635514275966877696',
#    'text': '@MashliLoves I’m so happy, proud, and excited for you Mashli!!! Yayayayay! God is faithful truly! ❤️💕'},
#   {'edit_history_tweet_ids': ['1635514257298038784'],
#    'id': '1635514257298038784',
#    'text': '@angepjm_ HAPPY BDAY :DDDD hope u have a wonderful day 💗'},
#   {'edit_history_tweet_ids': ['1635514149982597121'],
#    'id': '1635514149982597121',
#    'text': '@eleariart i’m so proud of you ele 🫂 i’m happy that you feel happy being yourself and you’ll always be loved! ilysm &lt;3'},
#   {'edit_history_tweet_ids': ['1635514138238795776'],
#    'id': '1635514138238795776',
#    'text': '@peachyjae04 Congratulation, Happy Graduation kak J semoga semuanya dilancarin ya \U0001faf6💐✨'},
#   {'edit_history_tweet_ids': ['1635514115837005828'],
#    'id': '1635514115837005828',
#    'text': '@iamvaldeeezII i am so proud and happy for u every time nakikita ko stories mo na ur doing so well i love you mal 😘'},
#   {'edit_history_tweet_ids': ['1635514104973762560'],
#    'id': '1635514104973762560',
#    'text': '@juliettespuppy We are so proud of you! Let us all be happy together in this FB family. Hope you have a good day today! ☀️'},
#   {'edit_history_tweet_ids': ['1635514048795262977'],
#    'id': '1635514048795262977',
#    'text': '@ShawnDotGames Welcome to the fibromyalgia spoonie family. There is so much overlap between the two, so happy you found out what it was. Water exercise is wonderful if you have that option or low impact exercise.'},
#   {'edit_history_tweet_ids': ['1635513994852040704'],
#    'id': '1635513994852040704',
#    'text': "A book is the best travel companion because they're entertaining, always happy to offer up great conversation, and they're never afraid to take a journey with us to new and wonderful places 🛫\n\nWhich book would you choose to keep you company on your travels?\n\n#UAEBBY https://t.co/HDXRRiiNwp"},
#   {'edit_history_tweet_ids': ['1635513978833993734'],
#    'id': '1635513978833993734',
#    'text': "What a Beautiful surprise to end the day!! So, Happy to see Jin!! Happy White Day!! I Love my lollipop 🍭 🍭🍭 Yes, I've been crying and missing you every day. Handsome and funny as ever!!🤣 ARMY IS SO PROUD OF YOU!! LOVE YOU MORE 💜😘🥰💕\n#JIN  #SEOKJIN\n#HappyWhiteDay 🍭 https://t.co/AkEgNedFhE"},
#   {'edit_history_tweet_ids': ['1635513696696016897'],
#    'id': '1635513696696016897',
#    'text': "Happy birthday Park Jihoon from Treasure! 🥳\nthank you for choosing to stay here and work hard until now. I'm proud of you oppa!\n\n─cont\n\nYOU MEAN THE WORLD TO ME\n#Shining314JihoonDay\n#해피믕믕데이_지훈아_생일축하해\n#セクシーで五めんっ\n@treasuremembers https://t.co/dlKTqLHGFN"},
#   {'edit_history_tweet_ids': ['1635513689427116034'],
#    'id': '1635513689427116034',
#    'text': '@65rigsby @kennygibsonnhs @NickiSparling1 @jomwlever @CatherineNeary @Cosmicwomble @BevMatthewsRN @irisbenson100 @NorthwayRuth @ccarmichael_83 @MarshaLTJones @oldnanchris @michelleburl @richardlittleda @Lodge4Betty @DrJude_G @kwelsh1 @LeighLeigh1991 @SAPHNAsharonOBE @CalvinMoorley @4AdsthePoet @KathEvans2 @DebEvans66 @Ewout1985 @TinaSouth3 @MAAPPUK @fiholley @JackieSmith_nmc @lynnturner31 @The_Debs_Effect @reboverend_RNc @KateSlater2 @warnetony @RoyLilley @NHSsafeguarding @Alison_Morton2 @FabNHSStuff @actionhappiness @gbtpo @PhilJeffery19 Good morning @65rigsby wishing you a happy Tuesday. Have a wonderful day filled with positivity and kindness❤️🌈 https://t.co/VfGpswxmOA'},
#   {'edit_history_tweet_ids': ['1635513576537354243'],
#    'id': '1635513576537354243',
#    'text': 'Good morning ! Have a great day! Let everything be simple today.... A happy smile... Light thoughts...Let the house be warm,  loved  ones are people are healthy, and our hearts are caim ! Have a wonderful mood,  TODAY, TOMORROW  AND  ALWAYS!❤️❤️❤️❤️💜💜💜💜💖💖💖💖 https://t.co/RTpPG4ABvX'},
#   {'edit_history_tweet_ids': ['1635513513052635138'],
#    'id': '1635513513052635138',
#    'text': "@DeputyARUUU Wow! I am very, very happy to see your message.Aruuu, Uuura... You guys were full of charm and were like 'muse✨' to me.\nI am also very grateful to @Lillith_sv for this wonderful request! \nThank you🌹"},
#   {'edit_history_tweet_ids': ['1635513452868390914'],
#    'id': '1635513452868390914',
#    'text': '@Iranobserver01 So happy for these countries &amp; the region. Makes me  proud to be Arab.'},
#   {'edit_history_tweet_ids': ['1635513425928536064'],
#    'id': '1635513425928536064',
#    'text': '@AniseMDiaz So proud and happy for you!! Can’t wait to see all that you accomplish 💪🏼 💪🏼 💪🏼'},
#   {'edit_history_tweet_ids': ['1635513411315302400'],
#    'id': '1635513411315302400',
#    'text': 'She’s happy 🥰 and that’s all that matters 💖 I will continue to do you proud and heal my baby 💝 https://t.co/gmrERUXaSX'},
#   {'edit_history_tweet_ids': ['1635513394915680256'],
#    'id': '1635513394915680256',
#    'text': 'On cloud nine right now 😄 The reception to my short film was so good and I got to talk to so many wonderful filmmakers. So happy to be making art with these amazing people 💖 https://t.co/MYshE6qu5v'},
#   {'edit_history_tweet_ids': ['1635513334350114818'],
#    'id': '1635513334350114818',
#    'text': "My dearest princess @bibblestars, happy white day and congratulation on passing your today's exam. https://t.co/Meia9E8ucq"},
#   {'edit_history_tweet_ids': ['1635513329387962368'],
#    'id': '1635513329387962368',
#    'text': '@_iloveitblue I’m proud of you too, Blue!!!! You try hard and you’re wonderful! https://t.co/1vvUD9Qvw9'},
#   {'edit_history_tweet_ids': ['1635513319661371393'],
#    'id': '1635513319661371393',
#    'text': '@Lovessiyaa121 Happy Tuesday &amp; wonderful week, My honey friend!!! 😴💤🌛💫🎵💙💜❤️🌹🙏✅🐐💯🎉🎊🎇🎶🎤 https://t.co/SzKpgokMO4'},
#   {'edit_history_tweet_ids': ['1635513305568624640'],
#    'id': '1635513305568624640',
#    'text': '#Happy_Birthday_Yoosung!! Hope you have a wonderful birthday! And I guess for today it’s ok to go play as much LOLOL as you want 😆 go wild! 🎂 and have some cake! 😋 🎂 🥳 🥳 🙌 🙌 🙌 https://t.co/MZniG7c0ad https://t.co/nOYmZZUt4o'},
#   {'edit_history_tweet_ids': ['1635513240145764353'],
#    'id': '1635513240145764353',
#    'text': 'A very Happy Birthday to Netra Bhargava, Gauri Gupta, Shagun Anshu Shekhar, Akshara Tiwari, and Bhanu Pratap Sharma. Stay Cheerful and blessed.\n\nWe hope you have an amazing day and many more wonderful birthdays ahead!! https://t.co/pGpZpi8fxI'},
#   {'edit_history_tweet_ids': ['1635513046964789249'],
#    'id': '1635513046964789249',
#    'text': '@RRK_Official_ Wish you happy birthday  madam 💐\nMany more happy returns of the day 🎂\nHave a wonderful life 🙏'},
#   {'edit_history_tweet_ids': ['1635513001750196227'],
#    'id': '1635513001750196227',
#    'text': 'Hey @emmalangevin I SEE YOU IN THE STREAMERS AWARD red carpet interview… AND I’m so happy to see you!!! You are sooooooo pretty!!! I’m proud of yooou wewweewoooo'},
#   {'edit_history_tweet_ids': ['1635512990047907841'],
#    'id': '1635512990047907841',
#    'text': '@starvinghurts_ Happy birthday!! I hope you have a wonderful birthday 🎂'},
#   {'edit_history_tweet_ids': ['1635512943709241347'],
#    'id': '1635512943709241347',
#    'text': 'A happy family life is a wonderful asset for any one. #渥太华   约  炮 https://t.co/TOHeuwL78J'},
#   {'edit_history_tweet_ids': ['1635512740814147584'],
#    'id': '1635512740814147584',
#    'text': '🥳🎊🎈 Wishing you a very Happy Birthday dear  may God bless you always with all the happiness and prosperity stay blessed always 🎂🍫💐🥳🎉🎊🎈Happy birthday \n@I_livewell\nYou are our  proud 👏\n\n@I_livewell\n\n@I_livewell https://t.co/rrxMazSFwQ'},
#   {'edit_history_tweet_ids': ['1635512617983971329'],
#    'id': '1635512617983971329',
#    'text': "Just had to take a moment to express my love for my OC, Nieva. She's just the cutest and most wonderful character I've ever created, and I can't help but feel proud of her. Every time I draw her, I'm reminded of how much she means to me. #Nievagonnadraw"},
#   {'edit_history_tweet_ids': ['1635512616599826432'],
#    'id': '1635512616599826432',
#    'text': '💜Army💜 come get your lollipops 🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭I’m so proud of you Seok Jin  and miss you so much happy white day and thank you for dressing up a bit for us 💜 may you be Brave,Tireless and Safe 💜   🍭🍭🍭🍭🍭🍭🍭🍭🍭🍭💜🍭🍭🍭🍭🍭🍭🍭 https://t.co/qAKWSGF2Vw'},
#   {'edit_history_tweet_ids': ['1635512483388481536'],
#    'id': '1635512483388481536',
#    'text': '@NithikShya Wonderful your reply\nI pleased\nHappy Tuesday to Nithik Ji'},
#   {'edit_history_tweet_ids': ['1635512229029367808'],
#    'id': '1635512229029367808',
#    'text': "did you know that you’re glowing? 🌼 your smile is so contagious, ssob. may you always be blissful. keep shining &amp; do whatever makes you happy. you're wonderful in your own way! \n\nwe’re always here for you no matter what 🤍\n\nwǒ ài nǐ, @davidlicauco #davidlicauco https://t.co/5G4lH1ww4Q"},
#   {'edit_history_tweet_ids': ['1635512192500989952'],
#    'id': '1635512192500989952',
#    'text': "Men and women are equal in worship, value and honor but we are not the same, we are created complimentary and different in wonderful ways Alhamdulillah ♡ \nSo let's stop pretending like to be valuable or successful or happy we have to imitate each other"},
#   {'edit_history_tweet_ids': ['1635512152269246464'],
#    'id': '1635512152269246464',
#    'text': '@dbc___ I will be staring at this for days to come. Thank you my friend! I’m happy and proud to support you and your work 🤝'},
#   {'edit_history_tweet_ids': ['1635511991329607681'],
#    'id': '1635511991329607681',
#    'text': '@BillyCrystal One of the greatest.\n“Iiiiiiit’s a wonderful night for an Oscar (Oscar,Oscar), who will win?”\nThe best host. An amazing actor. An excellent  born entertainer. Happy bday! 🇮🇹\U0001faf6🏼 https://t.co/K58W6VBPHL'},
#   {'edit_history_tweet_ids': ['1635511879169884160'],
#    'id': '1635511879169884160',
#    'text': "@3KMOfficial It's a very wonderful project. I feel avant-garde and sharpened sensibility. I'm so happy if you give me this one that I'm going to incontinence!\n\n@egaplek11 \n@Siloman222 \n@sisianjay11\n\n#3KM #AIRDROP"},
#   {'edit_history_tweet_ids': ['1635511870193795074'],
#    'id': '1635511870193795074',
#    'text': '@BQQuinn Happy Birthday! Hope you have a wonderful relaxing day! #tesd4eva listening to #tesd has helped me so much lately and I hope you have the great birthday you deserve dude. https://t.co/1nx44PHxXg'},
#   {'edit_history_tweet_ids': ['1635511829928767489'],
#    'id': '1635511829928767489',
#    'text': 'why are you so happy that a student is being targeted by her manipulative dance teacher to the point where she injured herself? why are you so proud that your characters are pretty much scared to experience moments of joy bc they know the other shoe is gonna drop??'},
#   {'edit_history_tweet_ids': ['1635511827672211461'],
#    'id': '1635511827672211461',
#    'text': 'why the hell are you so proud to make black teenage girl athletes go through trauma with the police? to make the coach feel as if SHE failed them? why are you so happy that the only time that team had a bonding moment was after TWO traumatic events within months of each other??'},
#   {'edit_history_tweet_ids': ['1635511794180710401'],
#    'id': '1635511794180710401',
#    'text': '@swiftieaus13 Happy birthday!! I hope you have a wonderful day 🥳'},
#   {'edit_history_tweet_ids': ['1635511710093135881'],
#    'id': '1635511710093135881',
#    'text': 'congratulation team India proud of you macha do\n@imVkohli @ImRo45'},
#   {'edit_history_tweet_ids': ['1635511681336979456'],
#    'id': '1635511681336979456',
#    'text': "@missteencrypto Happy birthday! 🎉🥳 It's amazing to see you growing into such a wonderful person over the past few years. Keep on shining bright and spreading positivity wherever you go. #birthdayvibes #grateful #celebratelife https://t.co/DVRDlYLOSn"},
#   {'edit_history_tweet_ids': ['1635511627868147713'],
#    'id': '1635511627868147713',
#    'text': 'I really miss my sister. happy heavenly 23rd Whitley Dawn. making you proud each and everyday. please continue to watch over us. I love you and I miss you. 💕'},
#   {'edit_history_tweet_ids': ['1635511605072113665'],
#    'id': '1635511605072113665',
#    'text': '@ssrajamouli @SRKxSuman @iamsrk We would love to see u collaborating SRK sir. This collaboration is been awaited for long hope someday we get to see. \n\nCongratulation for Oscar n we are damm proud.'},
#   {'edit_history_tweet_ids': ['1635511580367659008'],
#    'id': '1635511580367659008',
#    'text': "@1AmyChew An Oscar to her credentials. It does not get better than this. Tahniah to Michelle Yeoh, we're proud and happy for you!"},
#   {'edit_history_tweet_ids': ['1635511441464733697'],
#    'id': '1635511441464733697',
#    'text': '@FBAexe Seeing other brothers being successful (even if its before me in sha Allah) makes me proud and happy for them. Allahumma Barik, May Allah bless you tremendously in your wealth and increase it!'},
#   {'edit_history_tweet_ids': ['1635511435966189570'],
#    'id': '1635511435966189570',
#    'text': "@_FriendUnfriend @GMMTV So wonderful &amp; handsome Ohm Pawat. Thanks God. Finally you have solo event again. Hope you have many more solo event dear Ohm. Let's support for Ohm's solo event. We always love, proud &amp; support for you. Keep fighting. God Bless You🧡🧡🧡 @ohmpawatt #ohmpawat #OHMarch #OHMorning"},
#   {'edit_history_tweet_ids': ['1635511393771311104'],
#    'id': '1635511393771311104',
#    'text': '@SheilaEdrummer @JuanJEscovedo Wishing you a happy &amp; wonderful Birthday Juan! 🎂🎉🎁'},
#   {'edit_history_tweet_ids': ['1635511379162730497'],
#    'id': '1635511379162730497',
#    'text': '@meanwhileinau @SenatorAntic What a great show. So proud of the ABC and happy my taxes are paying for it. Paying your salary to spread hate? Not so happy.'},
#   {'edit_history_tweet_ids': ['1635511219627909121'],
#    'id': '1635511219627909121',
#    'text': '@AuschwitzMuseum Such a happy and cheeky little chappie. I wonder who he could have become and what wonderful things he could have done 😢x'},
#   {'edit_history_tweet_ids': ['1635511201642815490'],
#    'id': '1635511201642815490',
#    'text': '@Bert98556673 Thank you kindly, Bert..☕️🌤🥰\nHappy🎶Tuesday &amp; a wonderful \nday to you too, friend.🙂🤗☕️🍀 https://t.co/0P4sDncjPo'},
#   {'edit_history_tweet_ids': ['1635511112543133696'],
#    'id': '1635511112543133696',
#    'text': "Feeling of joy and national pride for India. A unique representation of the diversity of talent and cultures celebrated at the Academy Awards, which definitely makes our heart smile. \n\nCongratulations #RRR team, we can't be more proud and happy !!! #RRRMovie #NaatuNaatuOscars"},
#   {'edit_history_tweet_ids': ['1635511073963925505'],
#    'id': '1635511073963925505',
#    'text': '@Anxsks What the fuk is there to be proud of? Unless you have a humiliation fetish, I can’t imagine any reason why your actually happy with this clown’s presidency'},
#   {'edit_history_tweet_ids': ['1635510957731622912'],
#    'id': '1635510957731622912',
#    'text': '@JittersUwU HAPPY BIRTHDAY JITTERS!!!!! hope you have a wonderful day!!!! 💕💕✨✨🎉🎉🥳🥳🥳'},
#   {'edit_history_tweet_ids': ['1635510955206377472'],
#    'id': '1635510955206377472',
#    'text': '@Brooklyn_Chase Happy Birthday Sunshine! Have a wonderful day! https://t.co/vmdPekhZDA'},
#   {'edit_history_tweet_ids': ['1635510916773969922'],
#    'id': '1635510916773969922',
#    'text': '@CelinaJaitly Hallo liebe Celina! I wish you and your family a wonderful Tuesday.Stay happy and healthy💘🌺🌼💐🌻🙂🌹💖💗😘😍🥰❤️🍀'},
#   {'edit_history_tweet_ids': ['1635510884285181953'],
#    'id': '1635510884285181953',
#    'text': "@vanillaprkj Happy b'day uri best leader💞\n\nI hope your birthday is full of sunshine and love! wishing you a wonderful birthday and a year of happiness and success✨\n\nYOU MEAN THE WORLD TO ME\n#Shining314JihoonDay\n#해피믕믕데이_지훈아_생일축하해\n#セクシーで五めんっパクジフン\n@treasuremembers https://t.co/NuXBLVO9TW"},
#   {'edit_history_tweet_ids': ['1635510811245543425'],
#    'id': '1635510811245543425',
#    'text': 'Happy birthday to Kenty &lt;3\nI hope you have another wonderful year! Thank you for everything. Love you always!! xoxo\n\nお誕生日おめでとう!👏🎂🎉💙 大好きだよ〜! 忙しくて1日遅れちゃったけど…LA時間ではセーフかな😭?\n\n#KentoNakajima \n#中島健人誕生祭2023\n#HBDKentoNakajima2023 https://t.co/qekzJJ2QtU'},
#   {'edit_history_tweet_ids': ['1635510784481538049'],
#    'id': '1635510784481538049',
#    'text': "Here's wishing the popular director @Dir_Lokesh a very happy birthday and a wonderful year!\n\n#HappyBirthdayLokeshKanagaraj #LokeshKanagaraj #HBDLokeshKanagaraj https://t.co/FDjkLEkfDE"},
#   {'edit_history_tweet_ids': ['1635510629619441664'],
#    'id': '1635510629619441664',
#    'text': 'Good Morning Tibette family Happy Tina Tuesday have a wonderful day everyone ❤️🥰 https://t.co/5DWBch5Fru'},
#   {'edit_history_tweet_ids': ['1635510595645521920'],
#    'id': '1635510595645521920',
#    'text': "@Paixingshop @PiCoreTeam It's been a very interesting and educating journey with Dr Kokkalis and Fan so far and I'm proud and very grateful to be a part of it from year 1. Happy birthday and long live the greatest Pi.🎉🎉🎉🎉🍻"},
#   {'edit_history_tweet_ids': ['1635510592940417024'],
#    'id': '1635510592940417024',
#    'text': '@Ver_Vermillion Happy White Day to you too, Kaichou! Hope ur having a wonderful day with those uh...belts :D'},
#   {'edit_history_tweet_ids': ['1635510584614752256'],
#    'id': '1635510584614752256',
#    'text': '@iamrodneysmith Happy birthday to your son.  Looks like he has a wonderful playground.  Now that’s it mowed he can run all around.  God’s blessings to you all!'},
#   {'edit_history_tweet_ids': ['1635510570148581377'],
#    'id': '1635510570148581377',
#    'text': "@hartatreasure @treasuremembers Happy b'day uri best leader💞\n\nI hope your birthday is full of sunshine and love! wishing you a wonderful birthday and a year of happiness and success✨\n\nYOU MEAN THE WORLD TO ME\n#Shining314JihoonDay\n#해피믕믕데이_지훈아_생일축하해\n#セクシーで五めんっパクジフン\n@treasuremembers"},
#   {'edit_history_tweet_ids': ['1635510438854008834'],
#    'id': '1635510438854008834',
#    'text': '@NikhilVardhan48 Chiru first Movie ki villu inka baitaki kuda raale villu troll chesthunnar chiru ni pilla hook gallu. He is so happy and proud. let him enjoy in his own way ❤️. Btw his dp was so cute'},
#   {'edit_history_tweet_ids': ['1635510417891164160'],
#    'id': '1635510417891164160',
#    'text': '@2istoomany Thank you so much juni!! 😭👏💗 Working with you makes me really proud. Wish us a wonderful experience! 😳🥰'},
#   {'edit_history_tweet_ids': ['1635510382226731010'],
#    'id': '1635510382226731010',
#    'text': 'One of my favorite things is watching people in my community start streaming and they get excited to show me all the stuff they have set up when I pop into chat and it makes me so happy and proud \U0001f979'},
#   {'edit_history_tweet_ids': ['1635510310726500352'],
#    'id': '1635510310726500352',
#    'text': "I'm very proud of both, I was so happy seeing them nominated. We saw them show an award on stage last year, this year they'll go get theirs and that's because of their hard work. There'll be many more awards for them, like they deserve. \n#Beckysangels #srchafreen https://t.co/ZQMINW7rq6"},
#   {'edit_history_tweet_ids': ['1635510276362735618'],
#    'id': '1635510276362735618',
#    'text': 'Im really proud at how much ive grown with my music and mixing my own stuff. Its been a while since ive been happy like this even if its just for the moment you know? Have a goodnight everyone &lt;3 https://t.co/zbwkphM2af'},
#   {'edit_history_tweet_ids': ['1635510263775387653'],
#    'id': '1635510263775387653',
#    'text': 'Thank you Techstars Tel Aviv Accelerator for believing in true innovation. Thank you for bringing this amazing group of founders together. And thank you for a great kick start to this wonderful journey 💪🔥\nWe at Merry Pop In are super proud and excited t…https://t.co/vXrpLp6MsH'},
#   {'edit_history_tweet_ids': ['1635510189234466816'],
#    'id': '1635510189234466816',
#    'text': 'Happy Birthday!🎂\nMy Dear Co - Brother @Tarak_Holic 🥳\nYour are Simply Incredible 💥 May you have another year full of wonderful things to unfold 🤘....\nHere is Special Wishes For You ..✨ https://t.co/E2fSVWvl8W'},
#   {'edit_history_tweet_ids': ['1635510161669234688'],
#    'id': '1635510161669234688',
#    'text': '@KalagaraHari @ASRA_Society @AoraIndia @MayoAnesthesia @NarouzeMD @Ropivacaine @vrushali_ponde @EMARIANOMD @jeffgadsden @Nadia_Hdz_MD @dr_rajgupta @DProvenzanoMD @nelkassabany @adstengel You’ll be under the very proud spiritual eyes of your father and all ancestors 🙏🏻! How wonderful.'},
#   {'edit_history_tweet_ids': ['1635510112344494080'],
#    'id': '1635510112344494080',
#    'text': '@nvkm_1964 Jai Shri Ram!! Jai Pavanputra Veer Hanuman!! 🙏🙏🙏🚩 Happy morning and a wonderful day ahead. \n😊🙏☕🍁🌸🌄🌸🍁'},
#   {'edit_history_tweet_ids': ['1635509991372144640'],
#    'id': '1635509991372144640',
#    'text': '@SusanadesF Happy Tuesday dear Susana 🌹☕\nHave a wonderful day 💕🌿🦋🥂 https://t.co/35QWmaazdT'}],
#  'meta': {'newest_id': '1635515948273750016',
#   'oldest_id': '1635509991372144640',
#   'result_count': 98,
#   'next_token': 'b26v89c19zqg8o3fqka105jqqwiez7swhasx97d0ciet9'}}
